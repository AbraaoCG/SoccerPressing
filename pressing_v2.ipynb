# %% [markdown]
# # Eficácia do Pressing no Futebol de Elite — Análise Quantitativa
#
# ## 1. Introdução e Objetivo
#
# Este notebook implementa a **metodologia inicial** da proposta de projeto (`Pressao_no_futebol_v1.pdf`), aplicada à **UEFA Euro 2020** (StatsBomb Open Data — dados de evento + freeze frames 360).
#
# A unidade de análise é o **evento individual de pressão** (`type_name == Pressure`) e a variável resposta é `recovered`: o time pressionante recuperou a bola em até 10 segundos.
#
# **Foco desta etapa:** avaliar o *input* do modelo. Cada feature candidata passa por **testes de hipótese formais** — qui-quadrado, Mann-Whitney, Wald, razão de verossimilhança (LRT) e permutação — para justificar empiricamente sua inclusão, conforme a Seção A.5 do PDF.
#
# A profundidade dos testes é controlada pela flag `TEST_LEVEL` na célula de configuração. Os resultados por variável são persistidos em `variable_analysis/` (Seção 5.6).

# %% [markdown]
# ## 2. Configuração e Carregamento de Dados

# %%
import json
import os
import warnings
from datetime import datetime
from pathlib import Path

import numpy as np
import pandas as pd
from scipy import stats
from shapely.geometry import Polygon, MultiPoint, Point
from shapely.ops import voronoi_diagram
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.multitest import multipletests
from statsmodels.stats.outliers_influence import variance_inflation_factor
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 160)
print('Bibliotecas carregadas.')
# Out:
# Bibliotecas carregadas.

# %%
# Nivel de testes de hipotese executados na Secao 5:
#   1 = triagem univariada (qui-quadrado / Mann-Whitney)             [padrao]
#   2 = + VIF + modelo logistico (Wald) + razao de verossimilhanca (LRT)
#   3 = + teste de permutacao
#   4 = Seleção Avançada de Features via Algoritmo Boruta (Machine Learning)
TEST_LEVEL = 4 

DATA_DIR = Path('StatsBomb_2/data')
if not DATA_DIR.exists():
    DATA_DIR = Path('C:\\Users\\rafam\\OneDrive\\Documentos\\Facul\\Tóp Esp em Controle e Automação - Cienc Dados Futebol\\trabalho final\\open-data\\data')

COMP_ID, SEASON_ID = 55, 43       # UEFA Euro 2020
FIELD_X, FIELD_Y = 120.0, 80.0    # campo StatsBomb
RECOVERY_WINDOW = 10.0            # janela de recuperacao (segundos)
ALPHA = 0.05                      # nivel de significancia
VAR_DIR = 'variable_analysis'     # pasta de saida das tabelas por variavel

print('TEST_LEVEL =', TEST_LEVEL)
print('Diretorio de dados:', DATA_DIR, '| existe:', DATA_DIR.exists())
# Out:
# TEST_LEVEL = 4
# Diretorio de dados: C:\Users\rafam\OneDrive\Documentos\Facul\Tóp Esp em Controle e Automação - Cienc Dados Futebol\trabalho final\open-data\data | existe: True

# %%
def load_json(path):
    with open(path, encoding='utf-8') as fh:
        return json.load(fh)

matches = load_json(DATA_DIR / 'matches' / str(COMP_ID) / (str(SEASON_ID) + '.json'))
match_ids = sorted(m['match_id'] for m in matches)
print(len(match_ids), 'jogos na UEFA Euro 2020')

events_parts = []
frames = {}
for mid in match_ids:
    raw = load_json(DATA_DIR / 'events' / (str(mid) + '.json'))
    edf = pd.json_normalize(raw, sep='_')
    edf['match_id'] = mid
    events_parts.append(edf)
    ts_path = DATA_DIR / 'three-sixty' / (str(mid) + '.json')
    if ts_path.exists():
        for fr in load_json(ts_path):
            frames[fr['event_uuid']] = fr

events = pd.concat(events_parts, ignore_index=True)
print('Total de eventos:', len(events))
print('Freeze frames 360 carregados:', len(frames))
# Out:
# 51 jogos na UEFA Euro 2020
# Total de eventos: 192692
# Freeze frames 360 carregados: 166892

# %% [markdown]
# ## 3. Unidade de Análise e Variável Resposta
#
# A unidade de análise é o evento de pressão. A resposta `recovered` é construída por **junção temporal** (`merge_asof`): para cada pressão, procura-se o próximo evento de recuperação (`Ball Recovery`, `Interception` ou `Duel` vencido) realizado pelo **mesmo time**, na mesma partida e período, dentro de 10 segundos.

# %%
def ts_to_seconds(ts):
    hh, mm, ss = ts.split(':')
    return int(hh) * 3600 + int(mm) * 60 + float(ss)

events['t'] = events['timestamp'].apply(ts_to_seconds)
events['t_match'] = events['minute'] * 60 + events['second']

pressures = events[events['type_name'] == 'Pressure'].copy()
print('Eventos de pressao:', len(pressures))

# Eventos de recuperacao de bola
if 'ball_recovery_recovery_failure' in events.columns:
    rec_fail = events['ball_recovery_recovery_failure'].fillna(False)
else:
    rec_fail = pd.Series(False, index=events.index)

duel_outcome = events.get('duel_outcome_name', pd.Series('', index=events.index)).fillna('')
duel_won = events['type_name'].eq('Duel') & duel_outcome.str.contains('Won|Success')

rec_mask = (
    (events['type_name'].eq('Ball Recovery') & ~rec_fail)
    | events['type_name'].eq('Interception')
    | duel_won
)
recoveries = events.loc[rec_mask, ['match_id', 'period', 'team_id', 't']].copy()
print('Eventos de recuperacao:', len(recoveries))

left = (pressures[['id', 'match_id', 'period', 'team_id', 't']]
        .rename(columns={'t': 't_press'}).sort_values('t_press'))
right = recoveries.rename(columns={'t': 't_rec'}).sort_values('t_rec')

matched = pd.merge_asof(
    left, right,
    left_on='t_press', right_on='t_rec',
    by=['match_id', 'period', 'team_id'],
    direction='forward', tolerance=RECOVERY_WINDOW)
matched['recovered'] = matched['t_rec'].notna().astype(int)

pressures = pressures.merge(matched[['id', 'recovered']], on='id', how='left')
pressures['recovered'] = pressures['recovered'].fillna(0).astype(int)
print('Taxa de recuperacao observada: %.1f%% (PDF: ~25.5%%)' % (100 * pressures['recovered'].mean()))
# Out:
# Eventos de pressao: 15958
# Eventos de recuperacao: 6901
# Taxa de recuperacao observada: 28.0% (PDF: ~25.5%)

# %% [markdown]
# ## 4. Engenharia de Features
#
# ### 4.1 Features posicionais (PDF 2.4.2)
#
# - `dist_to_goal`: distância euclidiana ao gol adversário (120, 40).
# - `zone`: terço do campo (Defensivo x≤40, Médio 40–80, Atacante >80).
# - `duration`: duração do evento de pressão (atributo direto).

# %%
xy = pressures['location'].apply(
    lambda v: v if isinstance(v, list) and len(v) == 2 else [np.nan, np.nan])
pressures['x'] = xy.apply(lambda v: v[0])
pressures['y'] = xy.apply(lambda v: v[1])

pressures['dist_to_goal'] = np.sqrt((FIELD_X - pressures['x']) ** 2 + (40.0 - pressures['y']) ** 2)
pressures['zone'] = pd.cut(pressures['x'], bins=[-0.1, 40, 80, 120.1],
                           labels=['Defensivo', 'Medio', 'Atacante']).astype(str)
pressures['duration'] = pressures['duration'].fillna(0.0)
print(pressures[['x', 'y', 'dist_to_goal', 'duration']].describe())
print(pressures['zone'].value_counts())
# Out:
#                   x             y  dist_to_goal      duration
# count  15958.000000  15958.000000  15958.000000  15958.000000
# mean      55.037072     40.633056     70.000674      0.915228
# std       28.424072     23.882409     26.433750      0.756337
# min        0.900000      0.100000      2.758623      0.017997
# 25%       32.200000     18.300000     49.942742      0.474278
# 50%       53.800000     41.650000     70.797316      0.710715
# 75%       76.500000     62.900000     91.284610      1.074663
# max      118.900000     80.000000    122.870379     11.408008
# zone
# Medio        7155
# Defensivo    5428
# Atacante     3375
# Name: count, dtype: int64

# %% [markdown]
# ### 4.2 Features de contexto de jogo (PDF 2.4.3)
#
# - `score_diff`: placar corrido (gols do time pressionante − gols do adversário) até o instante da pressão. Gols vêm de `Shot` com `outcome == Goal` e de eventos `Own Goal For`.
# - `minute`: minuto da partida (atributo direto).

# %%
shot_outcome = events.get('shot_outcome_name', pd.Series('', index=events.index))
goals = events[
    (events['type_name'].eq('Shot') & shot_outcome.eq('Goal'))
    | events['type_name'].eq('Own Goal For')
][['match_id', 'team_id', 't_match']].copy()
print('Gols identificados:', len(goals))

score_diff = pd.Series(0, index=pressures.index, dtype=int)
for mid, grp in pressures.groupby('match_id'):
    g = goals[goals['match_id'] == mid]
    g_t = g['t_match'].to_numpy()
    g_team = g['team_id'].to_numpy()
    for idx, team, tm in zip(grp.index, grp['team_id'].to_numpy(), grp['t_match'].to_numpy()):
        before = g_t <= tm
        own = int(((g_team == team) & before).sum())
        opp = int(((g_team != team) & before).sum())
        score_diff.at[idx] = own - opp

pressures['score_diff'] = score_diff
print(pressures['score_diff'].value_counts().sort_index())
# Out:
# Gols identificados: 166
# score_diff
# -5      53
# -4      47
# -3     160
# -2     867
# -1    2835
#  0    7941
#  1    2997
#  2     822
#  3     145
#  4      62
#  5      29
# Name: count, dtype: int64

# %% [markdown]
# ### 4.3 Features táticas (PDF 2.4.4)
#
# O time pressionado é o `possession_team` da pressão.
#
# - `trigger_type`: tipo do evento mais recente do time pressionado antes da pressão (`merge_asof` backward, 5 s).
# - `action_under_pressure`: evento do time pressionado sob pressão mais próximo (`merge_asof` nearest, 2 s).
# - `is_counterpress`: a pressão ocorreu ≤5 s após perda de bola do próprio time (`Dispossessed`, `Miscontrol`, `Pass` incompleto/fora). Comparado com o atributo nativo `counterpress`.

# %%
ev_all = events[['match_id', 'period', 't', 'team_id', 'type_name', 'under_pressure']].copy()

# trigger_type: ultimo evento do time pressionado antes da pressao
trig_left = (pressures[['id', 'match_id', 'period', 't', 'possession_team_id']]
             .rename(columns={'possession_team_id': 'side'}).sort_values('t'))
trig_right = (ev_all.rename(columns={'team_id': 'side', 'type_name': 'trigger_type'})
              [['match_id', 'period', 't', 'side', 'trigger_type']].sort_values('t'))
trig = pd.merge_asof(trig_left, trig_right, on='t',
                     by=['match_id', 'period', 'side'],
                     direction='backward', tolerance=5.0)
pressures = pressures.merge(trig[['id', 'trigger_type']], on='id', how='left')

# action_under_pressure: evento do time pressionado sob pressao
aup_right = (ev_all[ev_all['under_pressure'] == True]
             .rename(columns={'team_id': 'side', 'type_name': 'action_under_pressure'})
             [['match_id', 'period', 't', 'side', 'action_under_pressure']].sort_values('t'))
aup = pd.merge_asof(trig_left, aup_right, on='t',
                    by=['match_id', 'period', 'side'],
                    direction='nearest', tolerance=2.0)
pressures = pressures.merge(aup[['id', 'action_under_pressure']], on='id', how='left')

# is_counterpress: perda do proprio time ate 5s antes
pass_outcome = events.get('pass_outcome_name', pd.Series('', index=events.index))
loss_mask = (events['type_name'].isin(['Dispossessed', 'Miscontrol'])
             | (events['type_name'].eq('Pass') & pass_outcome.isin(['Incomplete', 'Out'])))
loss = events.loc[loss_mask, ['match_id', 'period', 't', 'team_id']].rename(columns={'team_id': 'side'}).copy()
loss['lost'] = 1
loss = loss.sort_values('t')
cp_left = (pressures[['id', 'match_id', 'period', 't', 'team_id']]
           .rename(columns={'team_id': 'side'}).sort_values('t'))
cp = pd.merge_asof(cp_left, loss, on='t', by=['match_id', 'period', 'side'],
                   direction='backward', tolerance=5.0)
cp['is_counterpress'] = cp['lost'].notna().astype(int)
pressures = pressures.merge(cp[['id', 'is_counterpress']], on='id', how='left')

print('trigger_type:')
print(pressures['trigger_type'].value_counts(dropna=False).head(8))
print('action_under_pressure:')
print(pressures['action_under_pressure'].value_counts(dropna=False).head(8))
print('is_counterpress (taxa): %.1f%%' % (100 * pressures['is_counterpress'].mean()))
if 'counterpress' in pressures.columns:
    nativo = pressures['counterpress'].fillna(False).astype(bool).mean()
    print('counterpress nativo StatsBomb (taxa): %.1f%%' % (100 * nativo))
# Out:
# trigger_type:
# trigger_type
# Pass             4037
# Ball Receipt*    4009
# Carry            4000
# Pressure         2354
# Ball Recovery     498
# NaN               269
# Duel              202
# Dribble           199
# Name: count, dtype: int64
# action_under_pressure:
# action_under_pressure
# Carry            5914
# Pass             3605
# NaN              2290
# Ball Receipt*    1956
# Dribble           518
# Dispossessed      385
# Duel              321
# Foul Won          258
# Name: count, dtype: int64
# is_counterpress (taxa): 24.7%
# counterpress nativo StatsBomb (taxa): 19.1%

# %% [markdown]
# ### 4.4 Ações defensivas concorrentes (PDF 2.4.5)
#
# `had_tackle`, `had_block`, `had_foul`: houve desarme / bloqueio / falta cometida pelo time pressionante em até 3 s após a pressão (`merge_asof` forward).

# %%
def had_within(press_df, subset, tol=3.0):
    right = subset[['match_id', 'period', 't', 'team_id']].rename(columns={'team_id': 'side'}).copy()
    right['flag'] = 1
    right = right.sort_values('t')
    lft = (press_df[['id', 'match_id', 'period', 't', 'team_id']]
           .rename(columns={'team_id': 'side'}).sort_values('t'))
    m = pd.merge_asof(lft, right, on='t', by=['match_id', 'period', 'side'],
                      direction='forward', tolerance=tol)
    return m.set_index('id')['flag'].notna().astype(int)

duel_type = events.get('duel_type_name', pd.Series('', index=events.index))
tackles = events[events['type_name'].eq('Duel') & duel_type.eq('Tackle')]
blocks = events[events['type_name'].eq('Block')]
fouls = events[events['type_name'].eq('Foul Committed')]

pressures = pressures.set_index('id')
for name, subset in [('had_tackle', tackles), ('had_block', blocks), ('had_foul', fouls)]:
    pressures[name] = had_within(pressures.reset_index(), subset)
pressures = pressures.reset_index()
print(pressures[['had_tackle', 'had_block', 'had_foul']].mean())
# Out:
# had_tackle    0.115365
# had_block     0.061537
# had_foul      0.077704
# dtype: float64

# %% [markdown]
# ### 4.5 Features 360 — freeze frame (PDF 2.4.1)
#
# Para cada pressão, o freeze frame é localizado por `event_uuid`. A posição da bola é aproximada pela `location` do evento de pressão. Companheiros são os jogadores com `teammate == True` (time pressionante).
#
# *Caveat:* o freeze frame 360 contém apenas jogadores **visíveis** no instante do evento.

# %%
F360_KEYS = ['n_teammates_10m', 'n_adversaries_5m', 'n_opponents_10m',
             'nearest_teammate_dist', 'nearest_opponent_dist',
             'numerical_superiority', 'pressing_compactness']

def frame_360_features(row):
    fr = frames.get(row['id'])
    if fr is None or pd.isna(row['x']):
        return pd.Series({k: np.nan for k in F360_KEYS})
    bx, by = row['x'], row['y']
    mate_d, opp_d = [], []
    for p in fr['freeze_frame']:
        loc = p['location']
        d = float(np.hypot(loc[0] - bx, loc[1] - by))
        if p.get('teammate'):
            mate_d.append(d)
        else:
            opp_d.append(d)
    mate_d = np.array(mate_d)
    opp_d = np.array(opp_d)
    n_tm10 = int((mate_d <= 10).sum())
    n_op10 = int((opp_d <= 10).sum())
    return pd.Series({
        'n_teammates_10m': n_tm10,
        'n_adversaries_5m': int((opp_d <= 5).sum()),
        'n_opponents_10m': n_op10,
        'nearest_teammate_dist': float(mate_d.min()) if len(mate_d) else np.nan,
        'nearest_opponent_dist': float(opp_d.min()) if len(opp_d) else np.nan,
        'numerical_superiority': n_tm10 - n_op10,
        'pressing_compactness': float(mate_d.std()) if len(mate_d) > 1 else np.nan,
    })

f360 = pressures.apply(frame_360_features, axis=1)
pressures = pd.concat([pressures, f360], axis=1)
print('Cobertura de freeze frame 360: %.1f%% das pressoes'
      % (100 * f360['n_teammates_10m'].notna().mean()))
print(f360.describe())
# Out:
# Cobertura de freeze frame 360: 87.7% das pressoes
#        n_teammates_10m  n_adversaries_5m  n_opponents_10m  nearest_teammate_dist  nearest_opponent_dist  numerical_superiority  pressing_compactness
# count     13999.000000      13999.000000     13999.000000           1.399900e+04           13999.000000           13999.000000          13983.000000
# mean          2.294664          1.043360         1.963997           1.653664e-06               3.164720               0.330666             10.560822
# std           1.192846          0.604945         1.035443           1.031630e-06               1.780916               1.233097              3.158684
# min           1.000000          0.000000         0.000000           0.000000e+00               0.207388              -6.000000              1.421092
# 25%           1.000000          1.000000         1.000000           7.864200e-07               1.888702               0.000000              8.198405
# 50%           2.000000          1.000000         2.000000           1.537754e-06               2.859939               0.000000             10.249607
# 75%           3.000000          1.000000         2.000000           2.157919e-06               4.086566               1.000000             12.642891
# max           9.000000          5.000000         9.000000           4.315837e-06              18.634780               6.000000             26.886812

# %% [markdown]
# ### 4.6 Features de Voronoi — Fase 1 (PDF Apêndice A.1)
#
# Diagrama de Voronoi sobre os jogadores visíveis, com células clipadas ao campo 120×80. O portador da bola é o adversário mais próximo da bola; o pressionante é o companheiro mais próximo.
#
# - `voronoi_area_carrier`: área da célula do portador.
# - `voronoi_area_presser`: área da célula do pressionante.
# - `voronoi_n_opp_neighbors`: nº de adversários com célula adjacente à do portador.
#
# *Observação:* o cálculo dos diagramas pode levar alguns minutos.

# %%
FIELD = Polygon([(0, 0), (FIELD_X, 0), (FIELD_X, FIELD_Y), (0, FIELD_Y)])
VOR_KEYS = ['voronoi_area_carrier', 'voronoi_area_presser', 'voronoi_n_opp_neighbors']

def voronoi_features(row):
    nan_out = pd.Series({k: np.nan for k in VOR_KEYS})
    fr = frames.get(row['id'])
    if fr is None or pd.isna(row['x']):
        return nan_out
    players = fr['freeze_frame']
    if len(players) < 4:
        return nan_out
    locs = [(float(p['location'][0]), float(p['location'][1])) for p in players]
    is_mate = [bool(p.get('teammate')) for p in players]
    try:
        diagram = voronoi_diagram(MultiPoint(locs), envelope=FIELD, edges=False)
        cells = [g.intersection(FIELD) for g in diagram.geoms]
    except Exception:
        return nan_out
    cell_of = [None] * len(players)
    for cell in cells:
        for i, (lx, ly) in enumerate(locs):
            if cell_of[i] is None and cell.covers(Point(lx, ly)):
                cell_of[i] = cell
    bx, by = row['x'], row['y']
    dist = [np.hypot(lx - bx, ly - by) for lx, ly in locs]
    opp = [i for i in range(len(players)) if not is_mate[i]]
    mate = [i for i in range(len(players)) if is_mate[i]]
    if not opp or not mate:
        return nan_out
    ci = min(opp, key=lambda i: dist[i])
    pi = min(mate, key=lambda i: dist[i])
    carrier, presser = cell_of[ci], cell_of[pi]
    if carrier is None or presser is None or carrier.is_empty:
        return nan_out
    neigh = 0
    for i in opp:
        if i == ci:
            continue
        c = cell_of[i]
        if c is not None and not c.is_empty and carrier.touches(c):
            neigh += 1
    return pd.Series({
        'voronoi_area_carrier': float(carrier.area),
        'voronoi_area_presser': float(presser.area),
        'voronoi_n_opp_neighbors': int(neigh),
    })

print('Calculando diagramas de Voronoi (pode levar alguns minutos)...')
vor = pressures.apply(voronoi_features, axis=1)
pressures = pd.concat([pressures, vor], axis=1)
print('Voronoi calculado para %.1f%% das pressoes'
      % (100 * vor['voronoi_area_carrier'].notna().mean()))
print(vor.describe())
# Out:
# Calculando diagramas de Voronoi (pode levar alguns minutos)...
# Voronoi calculado para 86.5% das pressoes
#        voronoi_area_carrier  voronoi_area_presser  voronoi_n_opp_neighbors
# count          13802.000000          13802.000000              13802.00000
# mean             254.061319            262.581445                  1.28235
# std              502.258948            517.570975                  0.97102
# min                1.926904              3.487626                  0.00000
# 25%               43.938849             54.884244                  1.00000
# 50%               82.920929            100.360654                  1.00000
# 75%              213.541454            215.496893                  2.00000
# max             6161.281540           7259.766635                  5.00000

# %% [markdown]
# ### 4.7 Dataset final
#
# Monta-se `df` com uma linha por pressão: a resposta `recovered`, o time pressionante e todas as features. Categorias raras de `trigger_type` e `action_under_pressure` são agrupadas em `Other`.

# %%
TRIG_KEEP = ['Pass', 'Carry', 'Ball Receipt*', 'Dribble']
AUP_KEEP = ['Pass', 'Carry', 'Ball Receipt*', 'Dribble']

def collapse(series, keep):
    return series.where(series.isin(keep), other='Other').fillna('Other')

pressures['trigger_type'] = collapse(pressures['trigger_type'], TRIG_KEEP)
pressures['action_under_pressure'] = collapse(pressures['action_under_pressure'], AUP_KEEP)

CONT = ['dist_to_goal', 'duration', 'minute', 'score_diff',
        'n_teammates_10m', 'n_adversaries_5m', 'n_opponents_10m',
        'nearest_teammate_dist', 'nearest_opponent_dist',
        'numerical_superiority', 'pressing_compactness',
        'voronoi_area_carrier', 'voronoi_area_presser', 'voronoi_n_opp_neighbors']
CAT = ['zone', 'trigger_type', 'action_under_pressure',
       'is_counterpress', 'had_tackle', 'had_block', 'had_foul']
BIN = ['is_counterpress', 'had_tackle', 'had_block', 'had_foul']

df = pressures[['recovered', 'team_name'] + CONT + CAT].copy()
for c in BIN:
    df[c] = df[c].fillna(0).astype(int)

print('Dataset final:', df.shape)
print('Taxa de recuperacao:', round(100 * df['recovered'].mean(), 1), '%')
print('Valores ausentes por coluna:')
print(df.isna().sum()[df.isna().sum() > 0])
df.head()
# Out:
# Dataset final: (15958, 23)
# Taxa de recuperacao: 28.0 %
# Valores ausentes por coluna:
# n_teammates_10m            1959
# n_adversaries_5m           1959
# n_opponents_10m            1959
# nearest_teammate_dist      1959
# nearest_opponent_dist      1959
# numerical_superiority      1959
# pressing_compactness       1975
# voronoi_area_carrier       2156
# voronoi_area_presser       2156
# voronoi_n_opp_neighbors    2156
# dtype: int64
#    recovered team_name  dist_to_goal  duration  minute  score_diff  n_teammates_10m  n_adversaries_5m  n_opponents_10m  nearest_teammate_dist  \
# 0          0     Italy     78.446160  0.080000       0           0              1.0               1.0              1.0           8.529922e-07
# 1          0     Italy     37.345147  0.160000       0           0              1.0               1.0              2.0           1.525879e-06
# 2          1    Turkey     91.626252  0.487834       0           0              4.0               2.0              2.0           1.572840e-06
# 3          0     Italy     45.135574  0.248605       1           0              2.0               3.0              5.0           1.572840e-06
# 4          0     Italy     39.527838  0.536926       1           0              3.0               2.0              5.0           1.537754e-06
#
#    nearest_opponent_dist  numerical_superiority  pressing_compactness  voronoi_area_carrier  voronoi_area_presser  voronoi_n_opp_neighbors       zone  \
# 0               0.635884                    0.0             14.705699            148.726395            579.834340                      1.0      Medio
# 1               2.341773                   -1.0             11.487131            243.866108            183.288450                      1.0   Atacante
# 2               2.088120                    2.0              7.513519             12.286530             69.419749                      1.0  Defensivo
# 3               2.776240                   -3.0             13.944111             32.731547             18.726720                      3.0   Atacante
# 4               3.323657                   -2.0             14.487838             23.928321             15.569417                      1.0   Atacante
#
#     trigger_type action_under_pressure  is_counterpress  had_tackle  had_block  had_foul
# 0           Pass                 Carry                0           0          0         0
# 1          Other                 Other                1           0          0         0
# 2           Pass         Ball Receipt*                0           0          0         0
# 3          Other                 Carry                1           0          0         0
# 4  Ball Receipt*                  Pass                1           0          0         0

# %%
print('player_name' in pressures.columns.to_list())
# Out:
# True

# %% [markdown]
# ## 5. Avaliação Estatística do Input (Testes de Hipótese)
#
# Esta é a etapa central: cada feature candidata é submetida a testes formais antes de compor o modelo.
#
# ### 5.1 Triagem univariada (qui-quadrado / Mann-Whitney) — `TEST_LEVEL >= 1`
#
# - **Features contínuas:** teste de Mann-Whitney U (não-paramétrico) e teste t de Welch comparando os grupos `recovered = 0` e `recovered = 1`.
# - **Features categóricas:** teste qui-quadrado de independência (feature × `recovered`) com Cramér's V como tamanho de efeito.
# - Correção para múltiplos testes: Bonferroni e Benjamini-Hochberg (FDR).

# %%
records = []
for c in CONT:
    g0 = df.loc[df['recovered'] == 0, c].dropna()
    g1 = df.loc[df['recovered'] == 1, c].dropna()
    u_stat, p_mw = stats.mannwhitneyu(g0, g1, alternative='two-sided')
    t_stat, p_t = stats.ttest_ind(g0, g1, equal_var=False)
    records.append({'feature': c, 'tipo': 'continua', 'teste': 'Mann-Whitney U',
                    'estatistica': u_stat, 'p_valor': p_mw, 'p_t_welch': p_t,
                    'media_rec0': g0.mean(), 'media_rec1': g1.mean(), 'efeito': np.nan})

for c in CAT:
    table = pd.crosstab(df[c].astype(str), df['recovered'])
    chi2, p_chi, dof, _ = stats.chi2_contingency(table)
    n = table.values.sum()
    cramer = np.sqrt(chi2 / (n * (min(table.shape) - 1)))
    records.append({'feature': c, 'tipo': 'categorica', 'teste': 'Qui-quadrado',
                    'estatistica': chi2, 'p_valor': p_chi, 'p_t_welch': np.nan,
                    'media_rec0': np.nan, 'media_rec1': np.nan, 'efeito': cramer})

df_univariate = pd.DataFrame(records)
p_safe = df_univariate['p_valor'].fillna(1.0)
df_univariate['p_bonferroni'] = multipletests(p_safe, method='bonferroni')[1]
df_univariate['p_bh'] = multipletests(p_safe, method='fdr_bh')[1]
df_univariate['significativa'] = df_univariate['p_bh'] < ALPHA
print('Features significativas (BH, alpha=%.2f): %d de %d'
      % (ALPHA, df_univariate['significativa'].sum(), len(df_univariate)))
df_univariate.sort_values('p_valor').round(5)
# Out:
# Features significativas (BH, alpha=0.05): 19 de 21
#                     feature        tipo           teste   estatistica  p_valor  p_t_welch  media_rec0  media_rec1   efeito  p_bonferroni     p_bh  \
# 18               had_tackle  categorica    Qui-quadrado  1.503383e+03  0.00000        NaN         NaN         NaN  0.30693       0.00000  0.00000
# 20                 had_foul  categorica    Qui-quadrado  4.245266e+02  0.00000        NaN         NaN         NaN  0.16310       0.00000  0.00000
# 16    action_under_pressure  categorica    Qui-quadrado  2.235308e+02  0.00000        NaN         NaN         NaN  0.11835       0.00000  0.00000
# 4           n_teammates_10m    continua  Mann-Whitney U  1.775373e+07  0.00000    0.00000     2.23291     2.45334      NaN       0.00000  0.00000
# 11     voronoi_area_carrier    continua  Mann-Whitney U  2.125272e+07  0.00000    0.00000   272.32607   207.28735      NaN       0.00000  0.00000
# 14                     zone  categorica    Qui-quadrado  7.620500e+01  0.00000        NaN         NaN         NaN  0.06910       0.00000  0.00000
# 15             trigger_type  categorica    Qui-quadrado  8.274972e+01  0.00000        NaN         NaN         NaN  0.07201       0.00000  0.00000
# 1                  duration    continua  Mann-Whitney U  2.744614e+07  0.00000    0.00011     0.92959     0.87833      NaN       0.00000  0.00000
# 0              dist_to_goal    continua  Mann-Whitney U  2.409740e+07  0.00000    0.00000    69.24845    71.93331      NaN       0.00000  0.00000
# 8     nearest_opponent_dist    continua  Mann-Whitney U  2.102737e+07  0.00000    0.00000     3.22260     3.01599      NaN       0.00000  0.00000
# 5          n_adversaries_5m    continua  Mann-Whitney U  1.879442e+07  0.00000    0.00000     1.02630     1.08720      NaN       0.00000  0.00000
# 9     numerical_superiority    continua  Mann-Whitney U  1.862477e+07  0.00000    0.00000     0.29701     0.41713      NaN       0.00000  0.00000
# 6           n_opponents_10m    continua  Mann-Whitney U  1.871764e+07  0.00000    0.00000     1.93589     2.03621      NaN       0.00001  0.00000
# 13  voronoi_n_opp_neighbors    continua  Mann-Whitney U  2.015510e+07  0.00000    0.00004     1.30375     1.22755      NaN       0.00009  0.00001
# 17          is_counterpress  categorica    Qui-quadrado  1.960106e+01  0.00001        NaN         NaN         NaN  0.03505       0.00020  0.00001
# 7     nearest_teammate_dist    continua  Mann-Whitney U  2.068367e+07  0.00002    0.00004     0.00000     0.00000      NaN       0.00036  0.00002
# 12     voronoi_area_presser    continua  Mann-Whitney U  1.992595e+07  0.00105    0.97655   262.66243   262.37404      NaN       0.02204  0.00130
# 10     pressing_compactness    continua  Mann-Whitney U  2.028796e+07  0.00777    0.00176    10.61199    10.42938      NaN       0.16320  0.00907
# 19                had_block  categorica    Qui-quadrado  5.294810e+00  0.02139        NaN         NaN         NaN  0.01822       0.44917  0.02364
# 2                    minute    continua  Mann-Whitney U  2.541473e+07  0.31156    0.29097    47.16358    47.71483      NaN       1.00000  0.32713
# 3                score_diff    continua  Mann-Whitney U  2.564279e+07  0.88092    0.44087    -0.00618     0.00850      NaN       1.00000  0.88092
#
#     significativa
# 18           True
# 20           True
# 16           True
# 4            True
# 11           True
# 14           True
# 15           True
# 1            True
# 0            True
# 8            True
# 5            True
# 9            True
# 6            True
# 13           True
# 17           True
# 7            True
# 12           True
# 10           True
# 19           True
# 2           False
# 3           False

# %% [markdown]
# ### 5.2 Multicolinearidade — VIF — `TEST_LEVEL >= 2`
#
# O *Variance Inflation Factor* é calculado sobre as features contínuas padronizadas. VIF ≥ 5 indica multicolinearidade relevante — a feature torna-se candidata a substituição (ver Apêndice A.4 do PDF).

# %%
if TEST_LEVEL >= 2:
    Xc = df[CONT].dropna()
    Xz = (Xc - Xc.mean()) / Xc.std()
    Xz = sm.add_constant(Xz)
    vif_vals = [variance_inflation_factor(Xz.values, i + 1) for i in range(len(CONT))]
    df_vif = pd.DataFrame({'feature': CONT, 'VIF': vif_vals})
    df_vif['multicolinear'] = df_vif['VIF'] >= 5
    print('VIF calculado sobre', len(Xc), 'pressoes com features 360/Voronoi completas.')
    display(df_vif.sort_values('VIF', ascending=False).round(3))
else:
    df_vif = None
    print('TEST_LEVEL < 2: VIF nao executado.')
# Out:
# VIF calculado sobre 13787 pressoes com features 360/Voronoi completas.
#                     feature    VIF  multicolinear
# 4           n_teammates_10m    inf           True
# 6           n_opponents_10m    inf           True
# 9     numerical_superiority    inf           True
# 5          n_adversaries_5m  1.858          False
# 0              dist_to_goal  1.622          False
# 8     nearest_opponent_dist  1.591          False
# 13  voronoi_n_opp_neighbors  1.375          False
# 7     nearest_teammate_dist  1.235          False
# 10     pressing_compactness  1.159          False
# 12     voronoi_area_presser  1.107          False
# 11     voronoi_area_carrier  1.094          False
# 1                  duration  1.025          False
# 3                score_diff  1.003          False
# 2                    minute  1.002          False

# %% [markdown]
# ### 5.3 Significância no modelo logístico — Wald — `TEST_LEVEL >= 2`
#
# Ajusta-se a regressão logística com **efeitos fixos de time** (`C(team_name)`). O teste de Wald avalia a significância de cada coeficiente. São reportados também os *odds ratios*, o Pseudo R² de McFadden e o AIC.

# %%
def build_formula(cont, cat, team=True):
    parts = list(cont) + ['C(%s)' % c for c in cat]
    if team:
        parts.append('C(team_name)')
    return 'recovered ~ ' + ' + '.join(parts)

if TEST_LEVEL >= 2:
    model_df = df.dropna(subset=CONT + CAT + ['recovered', 'team_name']).copy()
    print('Ajustando modelo logistico em', len(model_df), 'pressoes...')
    logit_full = smf.logit(build_formula(CONT, CAT), data=model_df).fit(disp=False, maxiter=200)
    print(logit_full.summary())
    or_ci = np.exp(logit_full.conf_int())
    or_ci.columns = ['or_ic_inf', 'or_ic_sup']
    df_wald = pd.DataFrame({
        'termo': logit_full.params.index,
        'coef': logit_full.params.values,
        'odds_ratio': np.exp(logit_full.params.values),
        'or_ic_inf': or_ci['or_ic_inf'].values,
        'or_ic_sup': or_ci['or_ic_sup'].values,
        'p_wald': logit_full.pvalues.values})
    print('Pseudo R2 (McFadden): %.4f | AIC: %.1f' % (logit_full.prsquared, logit_full.aic))
    display(df_wald[~df_wald['termo'].str.contains('team_name')].round(4))
else:
    logit_full = None
    df_wald = None
    print('TEST_LEVEL < 2: modelo logistico / Wald nao executado.')
# Out:
# Ajustando modelo logistico em 13787 pressoes...
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              recovered   No. Observations:                13787
# Model:                          Logit   Df Residuals:                    13736
# Method:                           MLE   Df Model:                           50
# Date:                Sat, 16 May 2026   Pseudo R-squ.:                  0.1137
# Time:                        14:13:38   Log-Likelihood:                -7255.0
# converged:                      False   LL-Null:                       -8186.0
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -0.8696      0.213     -4.084      0.000      -1.287      -0.452
# C(zone)[T.Defensivo]                    0.3950      0.141      2.799      0.005       0.118       0.672
# C(zone)[T.Medio]                        0.0784      0.083      0.939      0.348      -0.085       0.242
# C(trigger_type)[T.Carry]               -0.0550      0.060     -0.923      0.356      -0.172       0.062
# C(trigger_type)[T.Dribble]              0.2021      0.193      1.049      0.294      -0.175       0.580
# C(trigger_type)[T.Other]                0.1713      0.072      2.379      0.017       0.030       0.312
# C(trigger_type)[T.Pass]                 0.0693      0.066      1.055      0.291      -0.059       0.198
# C(action_under_pressure)[T.Carry]      -0.1406      0.077     -1.835      0.066      -0.291       0.010
# C(action_under_pressure)[T.Dribble]     0.0889      0.138      0.647      0.518      -0.181       0.359
# C(action_under_pressure)[T.Other]       0.2224      0.086      2.600      0.009       0.055       0.390
# C(action_under_pressure)[T.Pass]       -0.1433      0.085     -1.686      0.092      -0.310       0.023
# C(is_counterpress)[T.1]                 0.1072      0.058      1.832      0.067      -0.007       0.222
# C(had_tackle)[T.1]                      1.7154      0.062     27.471      0.000       1.593       1.838
# C(had_block)[T.1]                       0.2049      0.080      2.556      0.011       0.048       0.362
# C(had_foul)[T.1]                       -2.6137      0.185    -14.112      0.000      -2.977      -2.251
# C(team_name)[T.Belgium]                -0.4254      0.141     -3.010      0.003      -0.702      -0.148
# C(team_name)[T.Croatia]                -0.4700      0.129     -3.632      0.000      -0.724      -0.216
# C(team_name)[T.Czech Republic]         -0.1929      0.127     -1.514      0.130      -0.443       0.057
# C(team_name)[T.Denmark]                -0.1509      0.128     -1.183      0.237      -0.401       0.099
# C(team_name)[T.England]                -0.3723      0.118     -3.159      0.002      -0.603      -0.141
# C(team_name)[T.Finland]                -0.5939      0.146     -4.080      0.000      -0.879      -0.309
# C(team_name)[T.France]                 -0.4006      0.143     -2.797      0.005      -0.681      -0.120
# C(team_name)[T.Germany]                -0.1844      0.144     -1.282      0.200      -0.466       0.098
# C(team_name)[T.Hungary]                -0.3172      0.160     -1.982      0.047      -0.631      -0.004
# C(team_name)[T.Italy]                  -0.3003      0.118     -2.538      0.011      -0.532      -0.068
# C(team_name)[T.Netherlands]            -0.1072      0.132     -0.813      0.416      -0.366       0.151
# C(team_name)[T.North Macedonia]        -0.0380      0.153     -0.249      0.803      -0.337       0.261
# C(team_name)[T.Poland]                 -0.1298      0.142     -0.916      0.360      -0.408       0.148
# C(team_name)[T.Portugal]               -0.1729      0.147     -1.176      0.240      -0.461       0.115
# C(team_name)[T.Russia]                 -0.0758      0.147     -0.515      0.607      -0.364       0.213
# C(team_name)[T.Scotland]               -0.2081      0.138     -1.506      0.132      -0.479       0.063
# C(team_name)[T.Slovakia]               -0.5838      0.145     -4.021      0.000      -0.868      -0.299
# C(team_name)[T.Spain]                  -0.0904      0.123     -0.735      0.462      -0.332       0.151
# C(team_name)[T.Sweden]                 -0.5784      0.150     -3.847      0.000      -0.873      -0.284
# C(team_name)[T.Switzerland]            -0.3742      0.124     -3.007      0.003      -0.618      -0.130
# C(team_name)[T.Turkey]                 -0.3106      0.140     -2.217      0.027      -0.585      -0.036
# C(team_name)[T.Ukraine]                -0.2585      0.126     -2.044      0.041      -0.506      -0.011
# C(team_name)[T.Wales]                  -0.4942      0.141     -3.517      0.000      -0.770      -0.219
# dist_to_goal                           -0.0047      0.002     -2.304      0.021      -0.009      -0.001
# duration                               -0.0388      0.029     -1.345      0.179      -0.095       0.018
# minute                                  0.0004      0.001      0.607      0.544      -0.001       0.002
# score_diff                              0.0180      0.021      0.875      0.382      -0.022       0.058
# n_teammates_10m                         0.0643   3.45e+05   1.87e-07      1.000   -6.76e+05    6.76e+05
# n_adversaries_5m                        0.0290      0.046      0.634      0.526      -0.061       0.119
# n_opponents_10m                         0.0414   3.45e+05    1.2e-07      1.000   -6.76e+05    6.76e+05
# nearest_teammate_dist                2.138e+04   2.21e+04      0.967      0.334    -2.2e+04    6.47e+04
# nearest_opponent_dist                  -0.0237      0.015     -1.589      0.112      -0.053       0.006
# numerical_superiority                   0.0229   3.45e+05   6.63e-08      1.000   -6.76e+05    6.76e+05
# pressing_compactness                    0.0017      0.007      0.239      0.811      -0.012       0.016
# voronoi_area_carrier                   -0.0001   4.66e-05     -2.918      0.004      -0.000   -4.46e-05
# voronoi_area_presser                 7.854e-05   4.15e-05      1.891      0.059   -2.86e-06       0.000
# voronoi_n_opp_neighbors                -0.0436      0.025     -1.737      0.082      -0.093       0.006
# =======================================================================================================
# Pseudo R2 (McFadden): 0.1137 | AIC: 14612.1
#                                   termo        coef  odds_ratio  or_ic_inf  or_ic_sup  p_wald
# 0                             Intercept     -0.8696      0.4191     0.2761     0.6362  0.0000
# 1                  C(zone)[T.Defensivo]      0.3950      1.4844     1.1257     1.9573  0.0051
# 2                      C(zone)[T.Medio]      0.0784      1.0815     0.9183     1.2738  0.3479
# 3              C(trigger_type)[T.Carry]     -0.0550      0.9465     0.8422     1.0638  0.3562
# 4            C(trigger_type)[T.Dribble]      0.2021      1.2240     0.8391     1.7854  0.2941
# 5              C(trigger_type)[T.Other]      0.1713      1.1869     1.0306     1.3668  0.0174
# 6               C(trigger_type)[T.Pass]      0.0693      1.0718     0.9423     1.2191  0.2912
# 7     C(action_under_pressure)[T.Carry]     -0.1406      0.8688     0.7477     1.0096  0.0665
# 8   C(action_under_pressure)[T.Dribble]      0.0889      1.0930     0.8347     1.4312  0.5179
# 9     C(action_under_pressure)[T.Other]      0.2224      1.2491     1.0563     1.4771  0.0093
# 10     C(action_under_pressure)[T.Pass]     -0.1433      0.8665     0.7335     1.0236  0.0918
# 11              C(is_counterpress)[T.1]      0.1072      1.1131     0.9925     1.2483  0.0670
# 12                   C(had_tackle)[T.1]      1.7154      5.5587     4.9184     6.2824  0.0000
# 13                    C(had_block)[T.1]      0.2049      1.2274     1.0490     1.4361  0.0106
# 14                     C(had_foul)[T.1]     -2.6137      0.0733     0.0510     0.1053  0.0000
# 38                         dist_to_goal     -0.0047      0.9953     0.9912     0.9993  0.0212
# 39                             duration     -0.0388      0.9619     0.9090     1.0179  0.1786
# 40                               minute      0.0004      1.0004     0.9991     1.0018  0.5441
# 41                           score_diff      0.0180      1.0181     0.9779     1.0600  0.3816
# 42                      n_teammates_10m      0.0643      1.0664     0.0000        inf  1.0000
# 43                     n_adversaries_5m      0.0290      1.0294     0.9412     1.1259  0.5260
# 44                      n_opponents_10m      0.0414      1.0423     0.0000        inf  1.0000
# 45                nearest_teammate_dist  21382.8947         inf     0.0000        inf  0.3338
# 46                nearest_opponent_dist     -0.0237      0.9765     0.9484     1.0056  0.1120
# 47                numerical_superiority      0.0229      1.0231     0.0000        inf  1.0000
# 48                 pressing_compactness      0.0017      1.0017     0.9877     1.0159  0.8111
# 49                 voronoi_area_carrier     -0.0001      0.9999     0.9998     1.0000  0.0035
# 50                 voronoi_area_presser      0.0001      1.0001     1.0000     1.0002  0.0586
# 51              voronoi_n_opp_neighbors     -0.0436      0.9573     0.9114     1.0056  0.0824

# %% [markdown]
# ### 5.4 Teste da razão de verossimilhança — LRT — `TEST_LEVEL >= 2`
#
# Para cada feature, ajusta-se um modelo reduzido (sem a feature) e compara-se com o modelo completo via estatística `2 · (logL_completo − logL_reduzido)`, distribuída como χ². Reporta-se também a variação de AIC (`delta_AIC > 0` indica que incluir a feature reduz o AIC).

# %%
if TEST_LEVEL >= 2:
    llf_full = logit_full.llf
    aic_full = logit_full.aic
    k_full = len(logit_full.params)
    lrt_records = []
    for c in CONT + CAT:
        red_cont = [x for x in CONT if x != c]
        red_cat = [x for x in CAT if x != c]
        red = smf.logit(build_formula(red_cont, red_cat), data=model_df).fit(disp=False, maxiter=200)
        lr = 2 * (llf_full - red.llf)
        ddof = max(k_full - len(red.params), 1)
        lrt_records.append({'feature': c, 'LR_stat': lr, 'df': ddof,
                            'p_lrt': stats.chi2.sf(lr, ddof),
                            'delta_AIC': red.aic - aic_full})
    df_lrt = pd.DataFrame(lrt_records)
    df_lrt['reduz_AIC'] = df_lrt['delta_AIC'] > 0
    display(df_lrt.sort_values('p_lrt').round(4))
else:
    df_lrt = None
    print('TEST_LEVEL < 2: LRT nao executado.')
# Out:
#                     feature   LR_stat  df   p_lrt  delta_AIC  reduz_AIC
# 18               had_tackle  809.0619   1  0.0000   807.0619       True
# 20                 had_foul  441.1862   1  0.0000   439.1862       True
# 16    action_under_pressure   44.4182   4  0.0000    36.4182       True
# 14                     zone   15.8893   2  0.0004    11.8893       True
# 11     voronoi_area_carrier    8.9177   1  0.0028     6.9177       True
# 19                had_block    6.3577   1  0.0117     4.3577       True
# 15             trigger_type   11.7143   4  0.0196     3.7143       True
# 0              dist_to_goal    4.4676   1  0.0345     2.4676       True
# 12     voronoi_area_presser    3.4560   1  0.0630     1.4560       True
# 17          is_counterpress    3.3104   1  0.0688     1.3104       True
# 13  voronoi_n_opp_neighbors    2.9664   1  0.0850     0.9664       True
# 8     nearest_opponent_dist    2.5041   1  0.1136     0.5041       True
# 1                  duration    1.8792   1  0.1704    -0.1208      False
# 3                score_diff    0.7817   1  0.3766    -1.2183      False
# 2                    minute    0.3999   1  0.5272    -1.6001      False
# 5          n_adversaries_5m    0.3936   1  0.5304    -1.6064      False
# 9     numerical_superiority    0.0000   1  1.0000     0.0000      False
# 10     pressing_compactness   -0.0098   1  1.0000    -2.0098      False
# 6           n_opponents_10m    0.0000   1  1.0000     0.0000      False
# 7     nearest_teammate_dist   -6.3451   1  1.0000    -8.3451      False
# 4           n_teammates_10m    0.0000   1  1.0000     0.0000      False

# %% [markdown]
# ### 5.5 Teste de permutação — `TEST_LEVEL >= 3`
#
# Para features com significância limítrofe (`0.01 <= p_BH <= 0.10`), o rótulo `recovered` é permutado 1000× para construir uma distribuição nula empírica da estatística de associação (χ² para categóricas, |t de Welch| para contínuas). O p-valor empírico confirma ou descarta a associação.

# %%
PERM_N = 1000

def permutation_pvalue(frame, feature, is_cat, n_perm=PERM_N, seed=42):
    rng = np.random.default_rng(seed)
    sub = frame[[feature, 'recovered']].dropna()
    y = sub['recovered'].to_numpy()
    if is_cat:
        x = sub[feature].astype(str).to_numpy()
        obs = stats.chi2_contingency(pd.crosstab(x, y))[0]
        count = 0
        for _ in range(n_perm):
            yp = rng.permutation(y)
            count += stats.chi2_contingency(pd.crosstab(x, yp))[0] >= obs
    else:
        x = sub[feature].to_numpy()
        obs = abs(stats.ttest_ind(x[y == 0], x[y == 1], equal_var=False)[0])
        count = 0
        for _ in range(n_perm):
            yp = rng.permutation(y)
            count += abs(stats.ttest_ind(x[yp == 0], x[yp == 1], equal_var=False)[0]) >= obs
    return (count + 1) / (n_perm + 1)

if TEST_LEVEL >= 3:
    border = df_univariate[(df_univariate['p_bh'] >= 0.01) & (df_univariate['p_bh'] <= 0.10)]
    if len(border) == 0:
        print('Nenhuma feature com significancia limitrofe (0.01 <= p_BH <= 0.10).')
        df_perm = pd.DataFrame(columns=['feature', 'p_permutacao'])
    else:
        perm_records = []
        for _, r in border.iterrows():
            p_emp = permutation_pvalue(df, r['feature'], r['tipo'] == 'categorica')
            perm_records.append({'feature': r['feature'], 'p_permutacao': p_emp})
            print('  %s: p_permutacao = %.4f' % (r['feature'], p_emp))
        df_perm = pd.DataFrame(perm_records)
else:
    df_perm = None
    print('TEST_LEVEL < 3: teste de permutacao nao executado.')
# Out:
# TEST_LEVEL < 3: teste de permutacao nao executado.

# %% [markdown]
# ### 5.6 Tabelas de análise por variável (`variable_analysis/`)
#
# Cada feature candidata tem sua análise completa registrada em arquivos CSV dentro de `variable_analysis/`, prontos para alimentar gráficos posteriores:
#
# - **`summary.csv`** — tabela mestra, uma linha por variável, com todos os campos escalares: identificação (grupo, referência no PDF, tipo, unidade), distribuição/qualidade dos dados, associação univariada (p-valores, `-log10(p)`, tamanho de efeito), multicolinearidade (VIF, correlação máxima), significância no modelo (coeficiente, odds ratio + IC 95%, Wald, LRT, ΔAIC), permutação e a decisão de inclusão.
# - **`breakdown_<feature>.csv`** — uma por variável, com a taxa de recuperação desagregada por faixa (decis, para contínuas) ou categoria, com IC 95% de Wilson — formato direto para curvas/barras.
#
# Campos dependentes de `TEST_LEVEL` (VIF, Wald, LRT, permutação) ficam como `NaN` quando o nível não os executa.

# %%
os.makedirs(VAR_DIR, exist_ok=True)

# Metadados por feature: (grupo, referencia PDF, descricao, calculo, unidade)
FEATURE_META = {
    'dist_to_goal': ('Posicional', '2.4.2', 'Distancia euclidiana ao gol adversario', 'sqrt((120-x)^2 + (40-y)^2)', 'metros'),
    'duration': ('Posicional', '2.4.2', 'Duracao do evento de pressao', 'atributo direto do evento', 'segundos'),
    'minute': ('Contexto de jogo', '2.4.3', 'Minuto da partida', 'atributo direto do evento', 'minuto'),
    'score_diff': ('Contexto de jogo', '2.4.3', 'Diferenca de gols (pressionante - adversario)', 'placar corrido ate o timestamp', 'gols'),
    'n_teammates_10m': ('Freeze frame 360', '2.4.1', 'Companheiros em 10m da bola', 'contagem no freeze frame', 'contagem'),
    'n_adversaries_5m': ('Freeze frame 360', '2.4.1', 'Adversarios em 5m da bola', 'contagem no freeze frame', 'contagem'),
    'n_opponents_10m': ('Freeze frame 360', '2.4.1', 'Adversarios em 10m da bola', 'contagem no freeze frame', 'contagem'),
    'nearest_teammate_dist': ('Freeze frame 360', '2.4.1', 'Distancia do companheiro mais proximo a bola', 'minimo das distancias', 'metros'),
    'nearest_opponent_dist': ('Freeze frame 360', '2.4.1', 'Distancia do adversario mais proximo a bola', 'minimo das distancias', 'metros'),
    'numerical_superiority': ('Freeze frame 360', '2.4.1', 'Superioridade numerica local', 'n_teammates_10m - n_opponents_10m', 'contagem'),
    'pressing_compactness': ('Freeze frame 360', '2.4.1', 'Compacidade do bloco de pressing', 'desvio padrao das distancias dos companheiros a bola', 'metros'),
    'voronoi_area_carrier': ('Voronoi', 'A.1', 'Area da celula de Voronoi do portador', 'diagrama de Voronoi clipado ao campo', 'm2'),
    'voronoi_area_presser': ('Voronoi', 'A.1', 'Area da celula de Voronoi do pressionante', 'diagrama de Voronoi clipado ao campo', 'm2'),
    'voronoi_n_opp_neighbors': ('Voronoi', 'A.1', 'Adversarios com celula adjacente a do portador', 'adjacencia no diagrama de Voronoi', 'contagem'),
    'zone': ('Posicional', '2.4.2', 'Terco do campo', 'Defensivo/Medio/Atacante por coordenada x', 'categorica'),
    'trigger_type': ('Tatica', '2.4.4', 'Evento do adversario antes da pressao', 'merge_asof backward 5s', 'categorica'),
    'action_under_pressure': ('Tatica', '2.4.4', 'Acao do adversario sob pressao', 'merge_asof nearest 2s', 'categorica'),
    'is_counterpress': ('Tatica', '2.4.4', 'Pressao ate 5s apos perda do proprio time', 'merge_asof backward 5s', 'binaria'),
    'had_tackle': ('Acoes defensivas concorrentes', '2.4.5', 'Desarme do time pressionante em ate 3s', 'merge_asof forward 3s', 'binaria'),
    'had_block': ('Acoes defensivas concorrentes', '2.4.5', 'Bloqueio do time pressionante em ate 3s', 'merge_asof forward 3s', 'binaria'),
    'had_foul': ('Acoes defensivas concorrentes', '2.4.5', 'Falta cometida pelo time pressionante em ate 3s', 'merge_asof forward 3s', 'binaria'),
}

def wilson_ci(k, n, z=1.96):
    if n == 0:
        return (np.nan, np.nan)
    p = k / n
    d = 1 + z * z / n
    centre = (p + z * z / (2 * n)) / d
    half = z * np.sqrt(p * (1 - p) / n + z * z / (4 * n * n)) / d
    return (max(0.0, centre - half), min(1.0, centre + half))

def cohens_d(a, b):
    na, nb = len(a), len(b)
    if na < 2 or nb < 2:
        return np.nan
    sa, sb = a.std(ddof=1), b.std(ddof=1)
    sp = np.sqrt(((na - 1) * sa * sa + (nb - 1) * sb * sb) / (na + nb - 2))
    return (b.mean() - a.mean()) / sp if sp > 0 else np.nan

def breakdown_continuous(feature, n_bins=10):
    sub = df[[feature, 'recovered']].dropna()
    try:
        bins = pd.qcut(sub[feature], q=n_bins, duplicates='drop')
    except Exception:
        bins = pd.cut(sub[feature], bins=min(n_bins, max(sub[feature].nunique(), 2)))
    rows = []
    for b, g in sub.groupby(bins, observed=True):
        n = len(g)
        k = int(g['recovered'].sum())
        lo, hi = wilson_ci(k, n)
        rows.append({'feature': feature, 'faixa': str(b), 'valor_representativo': g[feature].mean(),
                     'n': n, 'n_recuperados': k, 'taxa_recuperacao': k / n if n else np.nan,
                     'ic_inf': lo, 'ic_sup': hi})
    return pd.DataFrame(rows)

def breakdown_categorical(feature):
    sub = df[[feature, 'recovered']].copy()
    sub[feature] = sub[feature].astype(str)
    rows = []
    for i, (cat, g) in enumerate(sub.groupby(feature, observed=True)):
        n = len(g)
        k = int(g['recovered'].sum())
        lo, hi = wilson_ci(k, n)
        rows.append({'feature': feature, 'faixa': cat, 'valor_representativo': i,
                     'n': n, 'n_recuperados': k, 'taxa_recuperacao': k / n if n else np.nan,
                     'ic_inf': lo, 'ic_sup': hi})
    return pd.DataFrame(rows)

print('Funcoes e metadados de analise por variavel carregados.')
# Out:
# Funcoes e metadados de analise por variavel carregados.

# %%
# Lookups dependentes do TEST_LEVEL
corr_matrix = df[CONT].corr().abs()
for _col in corr_matrix.columns:
    corr_matrix.loc[_col, _col] = np.nan

wald_lookup = {}
if logit_full is not None:
    ci = np.exp(logit_full.conf_int())
    ci.columns = ['or_lo', 'or_hi']
    for term in logit_full.params.index:
        wald_lookup[term] = {'coef': logit_full.params[term], 'or': np.exp(logit_full.params[term]),
                             'or_lo': ci.loc[term, 'or_lo'], 'or_hi': ci.loc[term, 'or_hi'],
                             'p': logit_full.pvalues[term]}

def wald_for_feature(feature, is_cat):
    if not wald_lookup:
        return []
    if is_cat:
        return [t for t in wald_lookup if t.startswith('C(%s)[' % feature)]
    return [feature] if feature in wald_lookup else []

def analisar_variavel(feature):
    is_cat = feature in CAT
    grupo, pdf_ref, descricao, calculo, unidade = FEATURE_META[feature]
    s = df[feature]
    n_obs = len(s)
    n_valid = int(s.notna().sum())
    n_miss = n_obs - n_valid
    row = {'feature': feature, 'grupo': grupo, 'pdf_referencia': pdf_ref,
           'tipo': 'binaria' if feature in BIN else ('categorica' if is_cat else 'continua'),
           'descricao': descricao, 'calculo': calculo, 'unidade': unidade,
           'n_obs': n_obs, 'n_validos': n_valid, 'n_missing': n_miss,
           'pct_missing': round(100 * n_miss / n_obs, 3),
           'taxa_recuperacao_global': round(df['recovered'].mean(), 4)}
    # Bloco B - distribuicao
    if is_cat:
        vc = s.astype(str).value_counts()
        row.update({'n_categorias': int(vc.size), 'categorias': '|'.join(map(str, vc.index)),
                    'categoria_modal': str(vc.index[0]), 'freq_modal': int(vc.iloc[0]),
                    'categoria_menos_frequente': str(vc.index[-1]), 'freq_minima': int(vc.iloc[-1])})
    else:
        v = s.dropna()
        q1, q3 = v.quantile(0.25), v.quantile(0.75)
        iqr = q3 - q1
        n_out = int(((v < q1 - 1.5 * iqr) | (v > q3 + 1.5 * iqr)).sum())
        row.update({'min': v.min(), 'max': v.max(), 'media': v.mean(), 'mediana': v.median(),
                    'desvio_padrao': v.std(), 'p25': q1, 'p75': q3, 'iqr': iqr,
                    'assimetria': v.skew(), 'curtose': v.kurt(), 'n_outliers': n_out})
    # Bloco C - associacao univariada
    u = df_univariate[df_univariate['feature'] == feature].iloc[0]
    p_raw = u['p_valor']
    row.update({'teste_univariado': u['teste'], 'estatistica_univariada': u['estatistica'],
                'p_valor': p_raw, 'p_bonferroni': u['p_bonferroni'], 'p_bh': u['p_bh'],
                'neg_log10_p': -np.log10(p_raw) if pd.notna(p_raw) and p_raw > 0 else np.nan,
                'significativa_univariada': bool(u['significativa'])})
    if is_cat:
        rates = df.groupby(df[feature].astype(str))['recovered'].mean()
        row.update({'tamanho_efeito': u['efeito'], 'tipo_efeito': 'Cramers V',
                    'media_rec0': np.nan, 'media_rec1': np.nan,
                    'mediana_rec0': np.nan, 'mediana_rec1': np.nan,
                    'diff_medias': np.nan, 'diff_padronizada': np.nan,
                    'direcao_efeito': 'maior taxa: %s' % rates.idxmax()})
    else:
        g0 = df.loc[df['recovered'] == 0, feature].dropna()
        g1 = df.loc[df['recovered'] == 1, feature].dropna()
        d = cohens_d(g0, g1)
        row.update({'tamanho_efeito': d, 'tipo_efeito': 'Cohen d',
                    'media_rec0': g0.mean(), 'media_rec1': g1.mean(),
                    'mediana_rec0': g0.median(), 'mediana_rec1': g1.median(),
                    'diff_medias': g1.mean() - g0.mean(), 'diff_padronizada': d,
                    'direcao_efeito': 'recupera mais com valor ' + ('alto' if g1.mean() >= g0.mean() else 'baixo')})
    # Bloco D - multicolinearidade
    if df_vif is not None and not is_cat:
        vr = df_vif[df_vif['feature'] == feature]
        row['VIF'] = float(vr['VIF'].iloc[0]) if len(vr) else np.nan
        row['multicolinear'] = bool(vr['multicolinear'].iloc[0]) if len(vr) else False
    else:
        row['VIF'] = np.nan
        row['multicolinear'] = False
    if not is_cat and feature in corr_matrix.columns:
        cm = corr_matrix[feature]
        row['corr_max_abs'] = cm.max()
        row['feature_mais_correlacionada'] = cm.idxmax() if cm.notna().any() else None
    else:
        row['corr_max_abs'] = np.nan
        row['feature_mais_correlacionada'] = None
    row['candidata_substituicao'] = bool((pd.notna(row['corr_max_abs']) and row['corr_max_abs'] > 0.8)
                                         or row['multicolinear'])
    # Bloco E - Wald
    terms = wald_for_feature(feature, is_cat)
    if terms:
        best = min(terms, key=lambda t: wald_lookup[t]['p'])
        w = wald_lookup[best]
        row.update({'coef_logit': w['coef'], 'odds_ratio': w['or'],
                    'or_ic_inf': w['or_lo'], 'or_ic_sup': w['or_hi'], 'p_wald': w['p']})
    else:
        row.update({'coef_logit': np.nan, 'odds_ratio': np.nan,
                    'or_ic_inf': np.nan, 'or_ic_sup': np.nan, 'p_wald': np.nan})
    # LRT
    if df_lrt is not None:
        lr = df_lrt[df_lrt['feature'] == feature]
        if len(lr):
            row.update({'LR_stat': lr['LR_stat'].iloc[0], 'df_lrt': lr['df'].iloc[0],
                        'p_lrt': lr['p_lrt'].iloc[0], 'delta_AIC': lr['delta_AIC'].iloc[0],
                        'reduz_AIC': bool(lr['reduz_AIC'].iloc[0])})
        else:
            row.update({'LR_stat': np.nan, 'df_lrt': np.nan, 'p_lrt': np.nan,
                        'delta_AIC': np.nan, 'reduz_AIC': False})
    else:
        row.update({'LR_stat': np.nan, 'df_lrt': np.nan, 'p_lrt': np.nan,
                    'delta_AIC': np.nan, 'reduz_AIC': False})
    row['significativa_modelo'] = bool(pd.notna(row['p_lrt']) and row['p_lrt'] < ALPHA)
    # Bloco F - permutacao
    if df_perm is not None and len(df_perm) and feature in set(df_perm['feature']):
        row['p_permutacao'] = float(df_perm.loc[df_perm['feature'] == feature, 'p_permutacao'].iloc[0])
        row['n_permutacoes'] = PERM_N
    else:
        row['p_permutacao'] = np.nan
        row['n_permutacoes'] = np.nan
    # Bloco G - decisao
    if not row['significativa_univariada']:
        dec, mot = 'EXCLUIR', 'sem associacao univariada (p_BH >= alpha)'
    elif row['multicolinear']:
        dec, mot = 'REVISAR', 'multicolinearidade (VIF >= 5)'
    elif df_lrt is not None and pd.notna(row['p_lrt']) and row['p_lrt'] >= ALPHA:
        dec, mot = 'EXCLUIR', 'nao significativa no LRT'
    else:
        dec, mot = 'INCLUIR', 'aprovada nos testes executados'
    row['decisao'] = dec
    row['motivo_decisao'] = mot
    row['test_level'] = TEST_LEVEL
    row['data_analise'] = datetime.now().isoformat(timespec='seconds')
    # tabela de breakdown por variavel
    bd = breakdown_categorical(feature) if is_cat else breakdown_continuous(feature)
    bd.to_csv(os.path.join(VAR_DIR, 'breakdown_%s.csv' % feature), index=False)
    return row

df_variable_analysis = pd.DataFrame([analisar_variavel(f) for f in CONT + CAT])
df_variable_analysis.to_csv(os.path.join(VAR_DIR, 'summary.csv'), index=False)
print('Tabela mestra salva em', os.path.join(VAR_DIR, 'summary.csv'), '| shape:', df_variable_analysis.shape)
print('Arquivos de breakdown gerados:', len(CONT + CAT), '(um por variavel)')
display(df_variable_analysis)
# Out:
# Tabela mestra salva em variable_analysis\summary.csv | shape: (21, 67)
# Arquivos de breakdown gerados: 21 (um por variavel)
#                     feature                          grupo pdf_referencia        tipo                                        descricao  \
# 0              dist_to_goal                     Posicional          2.4.2    continua           Distancia euclidiana ao gol adversario
# 1                  duration                     Posicional          2.4.2    continua                     Duracao do evento de pressao
# 2                    minute               Contexto de jogo          2.4.3    continua                                Minuto da partida
# 3                score_diff               Contexto de jogo          2.4.3    continua    Diferenca de gols (pressionante - adversario)
# 4           n_teammates_10m               Freeze frame 360          2.4.1    continua                      Companheiros em 10m da bola
# 5          n_adversaries_5m               Freeze frame 360          2.4.1    continua                        Adversarios em 5m da bola
# 6           n_opponents_10m               Freeze frame 360          2.4.1    continua                       Adversarios em 10m da bola
# 7     nearest_teammate_dist               Freeze frame 360          2.4.1    continua     Distancia do companheiro mais proximo a bola
# 8     nearest_opponent_dist               Freeze frame 360          2.4.1    continua      Distancia do adversario mais proximo a bola
# 9     numerical_superiority               Freeze frame 360          2.4.1    continua                     Superioridade numerica local
# 10     pressing_compactness               Freeze frame 360          2.4.1    continua                 Compacidade do bloco de pressing
# 11     voronoi_area_carrier                        Voronoi            A.1    continua            Area da celula de Voronoi do portador
# 12     voronoi_area_presser                        Voronoi            A.1    continua        Area da celula de Voronoi do pressionante
# 13  voronoi_n_opp_neighbors                        Voronoi            A.1    continua   Adversarios com celula adjacente a do portador
# 14                     zone                     Posicional          2.4.2  categorica                                   Terco do campo
# 15             trigger_type                         Tatica          2.4.4  categorica            Evento do adversario antes da pressao
# 16    action_under_pressure                         Tatica          2.4.4  categorica                   Acao do adversario sob pressao
# 17          is_counterpress                         Tatica          2.4.4     binaria        Pressao ate 5s apos perda do proprio time
# 18               had_tackle  Acoes defensivas concorrentes          2.4.5     binaria           Desarme do time pressionante em ate 3s
# 19                had_block  Acoes defensivas concorrentes          2.4.5     binaria          Bloqueio do time pressionante em ate 3s
# 20                 had_foul  Acoes defensivas concorrentes          2.4.5     binaria  Falta cometida pelo time pressionante em ate 3s
#
#                                               calculo     unidade  n_obs  n_validos  n_missing  pct_missing  taxa_recuperacao_global       min          max  \
# 0                          sqrt((120-x)^2 + (40-y)^2)      metros  15958      15958          0        0.000                   0.2802  2.758623   122.870379
# 1                           atributo direto do evento    segundos  15958      15958          0        0.000                   0.2802  0.017997    11.408008
# 2                           atributo direto do evento      minuto  15958      15958          0        0.000                   0.2802  0.000000   124.000000
# 3                      placar corrido ate o timestamp        gols  15958      15958          0        0.000                   0.2802 -5.000000     5.000000
# 4                            contagem no freeze frame    contagem  15958      13999       1959       12.276                   0.2802  1.000000     9.000000
# 5                            contagem no freeze frame    contagem  15958      13999       1959       12.276                   0.2802  0.000000     5.000000
# 6                            contagem no freeze frame    contagem  15958      13999       1959       12.276                   0.2802  0.000000     9.000000
# 7                               minimo das distancias      metros  15958      13999       1959       12.276                   0.2802  0.000000     0.000004
# 8                               minimo das distancias      metros  15958      13999       1959       12.276                   0.2802  0.207388    18.634780
# 9                   n_teammates_10m - n_opponents_10m    contagem  15958      13999       1959       12.276                   0.2802 -6.000000     6.000000
# 10  desvio padrao das distancias dos companheiros ...      metros  15958      13983       1975       12.376                   0.2802  1.421092    26.886812
# 11               diagrama de Voronoi clipado ao campo          m2  15958      13802       2156       13.510                   0.2802  1.926904  6161.281540
# 12               diagrama de Voronoi clipado ao campo          m2  15958      13802       2156       13.510                   0.2802  3.487626  7259.766635
# 13                  adjacencia no diagrama de Voronoi    contagem  15958      13802       2156       13.510                   0.2802  0.000000     5.000000
# 14          Defensivo/Medio/Atacante por coordenada x  categorica  15958      15958          0        0.000                   0.2802       NaN          NaN
# 15                             merge_asof backward 5s  categorica  15958      15958          0        0.000                   0.2802       NaN          NaN
# 16                              merge_asof nearest 2s  categorica  15958      15958          0        0.000                   0.2802       NaN          NaN
# 17                             merge_asof backward 5s     binaria  15958      15958          0        0.000                   0.2802       NaN          NaN
# 18                              merge_asof forward 3s     binaria  15958      15958          0        0.000                   0.2802       NaN          NaN
# 19                              merge_asof forward 3s     binaria  15958      15958          0        0.000                   0.2802       NaN          NaN
# 20                              merge_asof forward 3s     binaria  15958      15958          0        0.000                   0.2802       NaN          NaN
#
#          media     mediana  desvio_padrao           p25         p75         iqr  assimetria    curtose  n_outliers teste_univariado  estatistica_univariada  \
# 0    70.000674   70.797316      26.433750  4.994274e+01   91.284610   41.341868   -0.151749  -0.832565         0.0   Mann-Whitney U            2.409740e+07
# 1     0.915228    0.710715       0.756337  4.742780e-01    1.074663    0.600385    3.237000  17.364499      1189.0   Mann-Whitney U            2.744614e+07
# 2    47.318022   46.000000      29.470871  2.200000e+01   71.000000   49.000000    0.191851  -0.928790         0.0   Mann-Whitney U            2.541473e+07
# 3    -0.002068    0.000000       1.094831  0.000000e+00    1.000000    1.000000   -0.120562   2.963911      1363.0   Mann-Whitney U            2.564279e+07
# 4     2.294664    2.000000       1.192846  1.000000e+00    3.000000    2.000000    0.952296   0.984927        54.0   Mann-Whitney U            1.775373e+07
# 5     1.043360    1.000000       0.604945  1.000000e+00    1.000000    0.000000    0.706632   2.414539      4165.0   Mann-Whitney U            1.879442e+07
# 6     1.963997    2.000000       1.035443  1.000000e+00    2.000000    1.000000    1.263623   2.439951      1103.0   Mann-Whitney U            1.871764e+07
# 7     0.000002    0.000002       0.000001  7.864200e-07    0.000002    0.000001    0.452344  -0.666622       174.0   Mann-Whitney U            2.068367e+07
# 8     3.164720    2.859939       1.780916  1.888702e+00    4.086566    2.197864    1.253722   2.980807       368.0   Mann-Whitney U            2.102737e+07
# 9     0.330666    0.000000       1.233097  0.000000e+00    1.000000    1.000000    0.033870   0.989167      1382.0   Mann-Whitney U            1.862477e+07
# 10   10.560822   10.249607       3.158684  8.198405e+00   12.642891    4.444487    0.493609   0.100550       107.0   Mann-Whitney U            2.028796e+07
# 11  254.061319   82.920929     502.258948  4.393885e+01  213.541454  169.602605    4.616122  28.243830      1797.0   Mann-Whitney U            2.125272e+07
# 12  262.581445  100.360654     517.570975  5.488424e+01  215.496893  160.612649    4.984908  33.400847      1716.0   Mann-Whitney U            1.992595e+07
# 13    1.282350    1.000000       0.971020  1.000000e+00    2.000000    1.000000    0.551216   0.041070       257.0   Mann-Whitney U            2.015510e+07
# 14         NaN         NaN            NaN           NaN         NaN         NaN         NaN        NaN         NaN     Qui-quadrado            7.620500e+01
# 15         NaN         NaN            NaN           NaN         NaN         NaN         NaN        NaN         NaN     Qui-quadrado            8.274972e+01
# 16         NaN         NaN            NaN           NaN         NaN         NaN         NaN        NaN         NaN     Qui-quadrado            2.235308e+02
# 17         NaN         NaN            NaN           NaN         NaN         NaN         NaN        NaN         NaN     Qui-quadrado            1.960106e+01
# 18         NaN         NaN            NaN           NaN         NaN         NaN         NaN        NaN         NaN     Qui-quadrado            1.503383e+03
# 19         NaN         NaN            NaN           NaN         NaN         NaN         NaN        NaN         NaN     Qui-quadrado            5.294808e+00
# 20         NaN         NaN            NaN           NaN         NaN         NaN         NaN        NaN         NaN     Qui-quadrado            4.245266e+02
#
#          p_valor  p_bonferroni          p_bh  neg_log10_p  significativa_univariada  tamanho_efeito tipo_efeito  media_rec0  media_rec1  mediana_rec0  \
# 0   1.426589e-09  2.995837e-08  3.328708e-09     8.845701                      True        0.101672     Cohen d   69.248450   71.933306     69.552282
# 1   1.371166e-11  2.879448e-10  3.599310e-11    10.862910                      True       -0.067806     Cohen d    0.929590    0.878328      0.720773
# 2   3.115551e-01  1.000000e+00  3.271328e-01     0.506465                     False        0.018705     Cohen d   47.163576   47.714829     46.000000
# 3   8.809227e-01  1.000000e+00  8.809227e-01     0.055062                     False        0.013408     Cohen d   -0.006181    0.008499      0.000000
# 4   2.623355e-22  5.509045e-21  1.377261e-21    21.581143                      True        0.185429     Cohen d    2.232907    2.453340      2.000000
# 5   2.245319e-08  4.715170e-07  4.286518e-08     7.648722                      True        0.100775     Cohen d    1.026298    1.087200      1.000000
# 6   2.561263e-07  5.378653e-06  4.137426e-07     6.591546                      True        0.096967     Cohen d    1.935894    2.036206      2.000000
# 7   1.712631e-05  3.596525e-04  2.247828e-05     4.766336                      True       -0.076912     Cohen d    0.000002    0.000002      0.000002
# 8   3.690498e-09  7.750045e-08  7.750045e-09     8.432915                      True       -0.116168     Cohen d    3.222605    3.015993      2.911528
# 9   3.686625e-08  7.741912e-07  6.451594e-08     7.433371                      True        0.097504     Cohen d    0.297013    0.417134      0.000000
# 10  7.771414e-03  1.631997e-01  9.066650e-03     2.109500                      True       -0.057829     Cohen d   10.611988   10.429380     10.303355
# 11  9.341930e-22  1.961805e-20  3.923610e-21    21.029563                      True       -0.129708     Cohen d  272.326068  207.287350     87.051502
# 12  1.049362e-03  2.203660e-02  1.296271e-03     2.979075                      True       -0.000557     Cohen d  262.662433  262.374044    102.461260
# 13  4.337042e-06  9.107789e-05  6.505564e-06     5.362806                      True       -0.078514     Cohen d    1.303748    1.227554      1.000000
# 14  2.833312e-17  5.949956e-16  9.916593e-17    16.547706                      True        0.069104   Cramers V         NaN         NaN           NaN
# 15  4.552342e-17  9.559917e-16  1.365702e-16    16.341765                      True        0.072010   Cramers V         NaN         NaN           NaN
# 16  3.258957e-47  6.843810e-46  2.281270e-46    46.486921                      True        0.118353   Cramers V         NaN         NaN           NaN
# 17  9.541612e-06  2.003739e-04  1.335826e-05     5.020378                      True        0.035047   Cramers V         NaN         NaN           NaN
# 18  0.000000e+00  0.000000e+00  0.000000e+00          NaN                      True        0.306934   Cramers V         NaN         NaN           NaN
# 19  2.138909e-02  4.491709e-01  2.364057e-02     1.669808                      True        0.018215   Cramers V         NaN         NaN           NaN
# 20  2.524621e-94  5.301705e-93  2.650853e-93    93.597804                      True        0.163103   Cramers V         NaN         NaN           NaN
#
#     mediana_rec1   diff_medias  diff_padronizada                 direcao_efeito       VIF  multicolinear  corr_max_abs feature_mais_correlacionada  \
# 0      74.103981  2.684856e+00          0.101672   recupera mais com valor alto  1.621833          False      0.447079       numerical_superiority
# 1       0.655457 -5.126170e-02         -0.067806  recupera mais com valor baixo  1.025253          False      0.108275             n_teammates_10m
# 2      46.000000  5.512527e-01          0.018705   recupera mais com valor alto  1.002313          False      0.025658       nearest_teammate_dist
# 3       0.000000  1.468012e-02          0.013408   recupera mais com valor alto  1.003043          False      0.025865                dist_to_goal
# 4       2.000000  2.204335e-01          0.185429   recupera mais com valor alto       inf           True      0.636098       numerical_superiority
# 5       1.000000  6.090290e-02          0.100775   recupera mais com valor alto  1.857607          False      0.574754       nearest_opponent_dist
# 6       2.000000  1.003124e-01          0.096967   recupera mais com valor alto       inf           True      0.466558            n_adversaries_5m
# 7       0.000002 -7.930074e-08         -0.076912  recupera mais com valor baixo  1.235033          False      0.425695                dist_to_goal
# 8       2.743193 -2.066118e-01         -0.116168  recupera mais com valor baixo  1.590842          False      0.574754            n_adversaries_5m
# 9       0.000000  1.201211e-01          0.097504   recupera mais com valor alto       inf           True      0.636098             n_teammates_10m
# 10     10.112388 -1.826076e-01         -0.057829  recupera mais com valor baixo  1.158620          False      0.339442             n_teammates_10m
# 11     72.002525 -6.503872e+01         -0.129708  recupera mais com valor baixo  1.093819          False      0.215079             n_teammates_10m
# 12     95.250143 -2.883883e-01         -0.000557  recupera mais com valor baixo  1.106665          False      0.249560             n_opponents_10m
# 13      1.000000 -7.619355e-02         -0.078514  recupera mais com valor baixo  1.374831          False      0.415475       numerical_superiority
# 14           NaN           NaN               NaN          maior taxa: Defensivo       NaN          False           NaN                         NaN
# 15           NaN           NaN               NaN              maior taxa: Other       NaN          False           NaN                         NaN
# 16           NaN           NaN               NaN            maior taxa: Dribble       NaN          False           NaN                         NaN
# 17           NaN           NaN               NaN                  maior taxa: 1       NaN          False           NaN                         NaN
# 18           NaN           NaN               NaN                  maior taxa: 1       NaN          False           NaN                         NaN
# 19           NaN           NaN               NaN                  maior taxa: 1       NaN          False           NaN                         NaN
# 20           NaN           NaN               NaN                  maior taxa: 0       NaN          False           NaN                         NaN
#
#     candidata_substituicao    coef_logit  odds_ratio  or_ic_inf  or_ic_sup         p_wald     LR_stat  df_lrt          p_lrt   delta_AIC  reduz_AIC  \
# 0                    False     -0.004749    0.995263   0.991250   0.999292   2.124025e-02    4.467575       1   3.454398e-02    2.467575       True
# 1                    False     -0.038827    0.961917   0.909008   1.017906   1.785874e-01    1.879177       1   1.704277e-01   -0.120823      False
# 2                    False      0.000424    1.000424   0.999055   1.001794   5.441476e-01    0.399867       1   5.271577e-01   -1.600133      False
# 3                    False      0.017983    1.018146   0.977945   1.059999   3.816103e-01    0.781744       1   3.766084e-01   -1.218256      False
# 4                     True      0.064304    1.066416   0.000000        inf   9.999999e-01    0.000000       1   1.000000e+00    0.000000      False
# 5                    False      0.028979    1.029403   0.941210   1.125861   5.259941e-01    0.393648       1   5.303883e-01   -1.606352      False
# 6                     True      0.041442    1.042313   0.000000        inf   9.999999e-01    0.000000       1   1.000000e+00    0.000000      False
# 7                    False  21382.894744         inf   0.000000        inf   3.337685e-01   -6.345066       1   1.000000e+00   -8.345066      False
# 8                    False     -0.023738    0.976541   0.948366   1.005554   1.120170e-01    2.504064       1   1.135530e-01    0.504064       True
# 9                     True      0.022861    1.023124   0.000000        inf   9.999999e-01    0.000000       1   1.000000e+00    0.000000      False
# 10                   False      0.001715    1.001717   0.987725   1.015907   8.110990e-01   -0.009819       1   1.000000e+00   -2.009819      False
# 11                   False     -0.000136    0.999864   0.999773   0.999955   3.525082e-03    8.917703       1   2.824195e-03    6.917703       True
# 12                   False      0.000079    1.000079   0.999997   1.000160   5.860778e-02    3.456025       1   6.302165e-02    1.456025       True
# 13                   False     -0.043597    0.957340   0.911389   1.005608   8.236072e-02    2.966410       1   8.501033e-02    0.966410       True
# 14                   False      0.394978    1.484351   1.125658   1.957343   5.131187e-03   15.889277       2   3.545581e-04   11.889277       True
# 15                   False      0.171311    1.186859   1.030612   1.366795   1.737707e-02   11.714331       4   1.960695e-02    3.714331       True
# 16                   False      0.222409    1.249083   1.056282   1.477075   9.320205e-03   44.418198       4   5.252538e-09   36.418198       True
# 17                   False      0.107156    1.113108   0.992530   1.248334   6.698237e-02    3.310384       1   6.884340e-02    1.310384       True
# 18                   False      1.715371    5.558740   4.918400   6.282447  3.949822e-166  809.061913       1  5.778988e-178  807.061913       True
# 19                   False      0.204859    1.227352   1.048962   1.436081   1.057378e-02    6.357670       1   1.168749e-02    4.357670       True
# 20                   False     -2.613743    0.073260   0.050958   0.105322   3.205425e-45  441.186184       1   5.974309e-98  439.186184       True
#
#     significativa_modelo  p_permutacao  n_permutacoes  decisao                             motivo_decisao  test_level         data_analise  n_categorias  \
# 0                   True           NaN            NaN  INCLUIR             aprovada nos testes executados           2  2026-05-16T14:14:10           NaN
# 1                  False           NaN            NaN  EXCLUIR                   nao significativa no LRT           2  2026-05-16T14:14:10           NaN
# 2                  False           NaN            NaN  EXCLUIR  sem associacao univariada (p_BH >= alpha)           2  2026-05-16T14:14:10           NaN
# 3                  False           NaN            NaN  EXCLUIR  sem associacao univariada (p_BH >= alpha)           2  2026-05-16T14:14:10           NaN
# 4                  False           NaN            NaN  REVISAR              multicolinearidade (VIF >= 5)           2  2026-05-16T14:14:10           NaN
# 5                  False           NaN            NaN  EXCLUIR                   nao significativa no LRT           2  2026-05-16T14:14:10           NaN
# 6                  False           NaN            NaN  REVISAR              multicolinearidade (VIF >= 5)           2  2026-05-16T14:14:10           NaN
# 7                  False           NaN            NaN  EXCLUIR                   nao significativa no LRT           2  2026-05-16T14:14:10           NaN
# 8                  False           NaN            NaN  EXCLUIR                   nao significativa no LRT           2  2026-05-16T14:14:10           NaN
# 9                  False           NaN            NaN  REVISAR              multicolinearidade (VIF >= 5)           2  2026-05-16T14:14:10           NaN
# 10                 False           NaN            NaN  EXCLUIR                   nao significativa no LRT           2  2026-05-16T14:14:10           NaN
# 11                  True           NaN            NaN  INCLUIR             aprovada nos testes executados           2  2026-05-16T14:14:10           NaN
# 12                 False           NaN            NaN  EXCLUIR                   nao significativa no LRT           2  2026-05-16T14:14:10           NaN
# 13                 False           NaN            NaN  EXCLUIR                   nao significativa no LRT           2  2026-05-16T14:14:10           NaN
# 14                  True           NaN            NaN  INCLUIR             aprovada nos testes executados           2  2026-05-16T14:14:10           3.0
# 15                  True           NaN            NaN  INCLUIR             aprovada nos testes executados           2  2026-05-16T14:14:10           5.0
# 16                  True           NaN            NaN  INCLUIR             aprovada nos testes executados           2  2026-05-16T14:14:10           5.0
# 17                 False           NaN            NaN  EXCLUIR                   nao significativa no LRT           2  2026-05-16T14:14:10           2.0
# 18                  True           NaN            NaN  INCLUIR             aprovada nos testes executados           2  2026-05-16T14:14:10           2.0
# 19                  True           NaN            NaN  INCLUIR             aprovada nos testes executados           2  2026-05-16T14:14:10           2.0
# 20                  True           NaN            NaN  INCLUIR             aprovada nos testes executados           2  2026-05-16T14:14:10           2.0
#
#                                 categorias categoria_modal  freq_modal categoria_menos_frequente  freq_minima
# 0                                      NaN             NaN         NaN                       NaN          NaN
# 1                                      NaN             NaN         NaN                       NaN          NaN
# 2                                      NaN             NaN         NaN                       NaN          NaN
# 3                                      NaN             NaN         NaN                       NaN          NaN
# 4                                      NaN             NaN         NaN                       NaN          NaN
# 5                                      NaN             NaN         NaN                       NaN          NaN
# 6                                      NaN             NaN         NaN                       NaN          NaN
# 7                                      NaN             NaN         NaN                       NaN          NaN
# 8                                      NaN             NaN         NaN                       NaN          NaN
# 9                                      NaN             NaN         NaN                       NaN          NaN
# 10                                     NaN             NaN         NaN                       NaN          NaN
# 11                                     NaN             NaN         NaN                       NaN          NaN
# 12                                     NaN             NaN         NaN                       NaN          NaN
# 13                                     NaN             NaN         NaN                       NaN          NaN
# 14                Medio|Defensivo|Atacante           Medio      7155.0                  Atacante       3375.0
# 15  Pass|Ball Receipt*|Carry|Other|Dribble            Pass      4037.0                   Dribble        199.0
# 16  Carry|Other|Pass|Ball Receipt*|Dribble           Carry      5914.0                   Dribble        518.0
# 17                                     0|1               0     12010.0                         1       3948.0
# 18                                     0|1               0     14117.0                         1       1841.0
# 19                                     0|1               0     14976.0                         1        982.0
# 20                                     0|1               0     14718.0                         1       1240.0

# %% [markdown]
# ## 6. Tabela Consolidada e Decisão de Inclusão
#
# Visão resumida da tabela mestra `variable_analysis/summary.csv` (montada na Seção 5.6), incluindo as features rejeitadas — a tabela de transparência exigida pela Seção A.5 do PDF. A decisão final segue a regra:
#
# - **EXCLUIR** se não houver associação univariada (BH);
# - **REVISAR** se VIF ≥ 5 (candidata a substituição por multicolinearidade);
# - **EXCLUIR** se não significativa no LRT (`TEST_LEVEL >= 2`);
# - **INCLUIR** caso contrário.

# %%
cols_view = ['feature', 'grupo', 'tipo', 'p_valor', 'p_bh', 'significativa_univariada',
             'tamanho_efeito', 'VIF', 'p_lrt', 'delta_AIC', 'p_permutacao', 'decisao']
consol = df_variable_analysis[cols_view].copy()
display(consol.sort_values('p_valor').round(4))
print()
print('Resumo das decisoes:')
print(df_variable_analysis['decisao'].value_counts())
print()
print('Arquivos gerados em', VAR_DIR + '/:')
print(' - summary.csv (', len(df_variable_analysis), 'variaveis )')
print(' - breakdown_<feature>.csv (', len(CONT + CAT), 'arquivos )')
# Out:
#                     feature                          grupo        tipo  p_valor    p_bh  significativa_univariada  tamanho_efeito     VIF   p_lrt  delta_AIC  \
# 18               had_tackle  Acoes defensivas concorrentes     binaria   0.0000  0.0000                      True          0.3069     NaN  0.0000   807.0619
# 20                 had_foul  Acoes defensivas concorrentes     binaria   0.0000  0.0000                      True          0.1631     NaN  0.0000   439.1862
# 16    action_under_pressure                         Tatica  categorica   0.0000  0.0000                      True          0.1184     NaN  0.0000    36.4182
# 4           n_teammates_10m               Freeze frame 360    continua   0.0000  0.0000                      True          0.1854     inf  1.0000     0.0000
# 11     voronoi_area_carrier                        Voronoi    continua   0.0000  0.0000                      True         -0.1297  1.0938  0.0028     6.9177
# 14                     zone                     Posicional  categorica   0.0000  0.0000                      True          0.0691     NaN  0.0004    11.8893
# 15             trigger_type                         Tatica  categorica   0.0000  0.0000                      True          0.0720     NaN  0.0196     3.7143
# 1                  duration                     Posicional    continua   0.0000  0.0000                      True         -0.0678  1.0253  0.1704    -0.1208
# 0              dist_to_goal                     Posicional    continua   0.0000  0.0000                      True          0.1017  1.6218  0.0345     2.4676
# 8     nearest_opponent_dist               Freeze frame 360    continua   0.0000  0.0000                      True         -0.1162  1.5908  0.1136     0.5041
# 5          n_adversaries_5m               Freeze frame 360    continua   0.0000  0.0000                      True          0.1008  1.8576  0.5304    -1.6064
# 9     numerical_superiority               Freeze frame 360    continua   0.0000  0.0000                      True          0.0975     inf  1.0000     0.0000
# 6           n_opponents_10m               Freeze frame 360    continua   0.0000  0.0000                      True          0.0970     inf  1.0000     0.0000
# 13  voronoi_n_opp_neighbors                        Voronoi    continua   0.0000  0.0000                      True         -0.0785  1.3748  0.0850     0.9664
# 17          is_counterpress                         Tatica     binaria   0.0000  0.0000                      True          0.0350     NaN  0.0688     1.3104
# 7     nearest_teammate_dist               Freeze frame 360    continua   0.0000  0.0000                      True         -0.0769  1.2350  1.0000    -8.3451
# 12     voronoi_area_presser                        Voronoi    continua   0.0010  0.0013                      True         -0.0006  1.1067  0.0630     1.4560
# 10     pressing_compactness               Freeze frame 360    continua   0.0078  0.0091                      True         -0.0578  1.1586  1.0000    -2.0098
# 19                had_block  Acoes defensivas concorrentes     binaria   0.0214  0.0236                      True          0.0182     NaN  0.0117     4.3577
# 2                    minute               Contexto de jogo    continua   0.3116  0.3271                     False          0.0187  1.0023  0.5272    -1.6001
# 3                score_diff               Contexto de jogo    continua   0.8809  0.8809                     False          0.0134  1.0030  0.3766    -1.2183
#
#     p_permutacao  decisao
# 18           NaN  INCLUIR
# 20           NaN  INCLUIR
# 16           NaN  INCLUIR
# 4            NaN  REVISAR
# 11           NaN  INCLUIR
# 14           NaN  INCLUIR
# 15           NaN  INCLUIR
# 1            NaN  EXCLUIR
# 0            NaN  INCLUIR
# 8            NaN  EXCLUIR
# 5            NaN  EXCLUIR
# 9            NaN  REVISAR
# 6            NaN  REVISAR
# 13           NaN  EXCLUIR
# 17           NaN  EXCLUIR
# 7            NaN  EXCLUIR
# 12           NaN  EXCLUIR
# 10           NaN  EXCLUIR
# 19           NaN  INCLUIR
# 2            NaN  EXCLUIR
# 3            NaN  EXCLUIR
# Resumo das decisoes:
# decisao
# EXCLUIR    10
# INCLUIR     8
# REVISAR     3
# Name: count, dtype: int64
#
# Arquivos gerados em variable_analysis/:
#  - summary.csv ( 21 variaveis )
#  - breakdown_<feature>.csv ( 21 arquivos )

# %% [markdown]
# # 7. SELEÇÃO VIA ALGORITMO BORUTA

# %%
if TEST_LEVEL >= 4:
    print("=== INICIANDO ALGORITMO BORUTA (DATASET FINAL: 'df') ===")
    
    from sklearn.ensemble import RandomForestClassifier
    from boruta import BorutaPy
    import pandas as pd
    import numpy as np

    # 1. Definição de todas as 21 variáveis candidatas avaliadas nos relatórios
    todas_21_features = [
        'had_tackle', 'had_foul', 'action_under_pressure', 'n_teammates_10m', 
        'voronoi_area_carrier', 'zone', 'trigger_type', 'duration', 'dist_to_goal', 
        'nearest_opponent_dist', 'n_adversaries_5m', 'numerical_superiority', 
        'n_opponents_10m', 'voronoi_n_opp_neighbours', 'is_counterpress', 
        'nearest_teammate_dist', 'voronoi_area_presser', 'pressing_compactness', 
        'had_block', 'minute', 'score_diff'
    ]
    
    # Validação: garante que apenas colunas existentes no dataset final 'df' entrem na lista
    features_validas = [feat for feat in todas_21_features if feat in df.columns]
    
    # Alerta se houver alguma divergência de nomenclatura nas colunas do seu dataframe final
    if len(features_validas) < len(todas_21_features):
        faltantes = set(todas_21_features) - set(features_validas)
        print(f"\n[AVISO] {len(faltantes)} variáveis não foram encontradas no DataFrame 'df' e foram ignoradas: {faltantes}")
        print("Verifique se há divergências de digitação em relação ao dataset final.\n")

    # 2. Tratamento de variáveis categóricas (One-Hot Encoding para o Scikit-Learn)
    # Aplicado diretamente sobre o fatiamento do dataset final 'df'
    X_encoded = pd.get_dummies(df[features_validas], drop_first=True)
    y_encoded = df['recovered'].values

    # Monitoramento e tratamento automático de valores nulos (NaNs) no dataframe final
    nan_counts = X_encoded.isna().sum()
    cols_com_nan = nan_counts[nan_counts > 0]
    if not cols_com_nan.empty:
        print(f"\n Detectados valores nulos (NaN) em {len(cols_com_nan)} colunas do 'df' pós-encoding:")
        for c, qtd in cols_com_nan.items():
            print(f" -> {c}: {qtd} linhas em branco.")
        
        # Preenchimento pela mediana para evitar falhas no Random Forest do Scikit-learn
        X_encoded = X_encoded.fillna(X_encoded.median())
    else:
        print("\n[OK] Nenhuma feature do dataset 'df' apresentou valores nulos (NaN).")

    print(f"Matriz de features estruturada para Machine Learning: {X_encoded.shape[1]} colunas pós-encoding.")
    
    # 3. Configuração do estimador base (Random Forest)
    rf_base = RandomForestClassifier(
        n_jobs=-1, 
        class_weight='balanced', 
        max_depth=5, 
        random_state=42
    )
    
    # 4. Inicialização e Ajuste do Boruta
    boruta_selector = BorutaPy(
        rf_base, 
        n_estimators='auto', 
        verbose=1, 
        alpha=0.05, 
        max_iter=100, 
        random_state=42
    )
    
    print("Rodando duelos contra as Shadow Features usando o dataset final 'df'...")
    boruta_selector.fit(X_encoded.values, y_encoded)
    
    # 5. Consolidação e Mapeamento dos Resultados
    boruta_results = pd.DataFrame({
        'feature_encoded': X_encoded.columns,
        'ranking': boruta_selector.ranking_,
        'support': boruta_selector.support_,
        'support_weak': boruta_selector.support_weak_
    })
    
    # Traduz as classificações do Boruta para as decisões de projeto
    def mapear_decisao_boruta(row):
        if row['support']:
            return 'INCLUIR'
        elif row['support_weak']:
            return 'REVISAR'
        else:
            return 'EXCLUIR'
            
    boruta_results['decisao'] = boruta_results.apply(mapear_decisao_boruta, axis=1)
    
    # Salva o arquivo atualizado no diretório correto do seu repositório
    os.makedirs("variable_analysis", exist_ok=True)
    boruta_results.to_csv("variable_analysis/boruta_full_ranking.csv", index=False)
    
    print("\n--- RESULTADO FINAL DO RANKING BORUTA (DATASET: df) ---")
    print(boruta_results[['feature_encoded', 'ranking', 'decisao']].sort_values(by='ranking').to_string(index=False))
# Out:
# === INICIANDO ALGORITMO BORUTA (DATASET FINAL: 'df') ===
#
# [AVISO] 1 variáveis não foram encontradas no DataFrame 'df' e foram ignoradas: {'voronoi_n_opp_neighbours'}
# Verifique se há divergências de digitação em relação ao dataset final.
#
#
#  Detectados valores nulos (NaN) em 9 colunas do 'df' pós-encoding:
#  -> n_teammates_10m: 1959 linhas em branco.
#  -> voronoi_area_carrier: 2156 linhas em branco.
#  -> nearest_opponent_dist: 1959 linhas em branco.
#  -> n_adversaries_5m: 1959 linhas em branco.
#  -> numerical_superiority: 1959 linhas em branco.
#  -> n_opponents_10m: 1959 linhas em branco.
#  -> nearest_teammate_dist: 1959 linhas em branco.
#  -> voronoi_area_presser: 2156 linhas em branco.
#  -> pressing_compactness: 1975 linhas em branco.
# Matriz de features estruturada para Machine Learning: 27 colunas pós-encoding.
# Rodando duelos contra as Shadow Features usando o dataset final 'df'...
# Iteration: 1 / 100
# Iteration: 2 / 100
# Iteration: 3 / 100
# Iteration: 4 / 100
# Iteration: 5 / 100
# Iteration: 6 / 100
# Iteration: 7 / 100
# Iteration: 8 / 100
# Iteration: 9 / 100
# Iteration: 10 / 100
# Iteration: 11 / 100
# Iteration: 12 / 100
# Iteration: 13 / 100
# Iteration: 14 / 100
# Iteration: 15 / 100
# Iteration: 16 / 100
# Iteration: 17 / 100
# Iteration: 18 / 100
# Iteration: 19 / 100
# Iteration: 20 / 100
# Iteration: 21 / 100
# Iteration: 22 / 100
# Iteration: 23 / 100
# Iteration: 24 / 100
# Iteration: 25 / 100
# Iteration: 26 / 100
# Iteration: 27 / 100
# Iteration: 28 / 100
# Iteration: 29 / 100
# Iteration: 30 / 100
# Iteration: 31 / 100
# Iteration: 32 / 100
# Iteration: 33 / 100
# Iteration: 34 / 100
# Iteration: 35 / 100
# Iteration: 36 / 100
# Iteration: 37 / 100
# Iteration: 38 / 100
# Iteration: 39 / 100
# Iteration: 40 / 100
# Iteration: 41 / 100
# Iteration: 42 / 100
# Iteration: 43 / 100
# Iteration: 44 / 100
# Iteration: 45 / 100
# Iteration: 46 / 100
# Iteration: 47 / 100
# Iteration: 48 / 100
# Iteration: 49 / 100
# Iteration: 50 / 100
# Iteration: 51 / 100
#
#
# BorutaPy finished running.
#
# Iteration: 	52 / 100
# Confirmed: 	13
# Tentative: 	0
# Rejected: 	14
#
# --- RESULTADO FINAL DO RANKING BORUTA (DATASET: df) ---
#               feature_encoded  ranking decisao
#                    had_tackle        1 INCLUIR
#                      had_foul        1 INCLUIR
#               n_teammates_10m        1 INCLUIR
#          voronoi_area_carrier        1 INCLUIR
#                      duration        1 INCLUIR
#                  dist_to_goal        1 INCLUIR
#         nearest_opponent_dist        1 INCLUIR
#          pressing_compactness        1 INCLUIR
#          voronoi_area_presser        1 INCLUIR
#                zone_Defensivo        1 INCLUIR
#    action_under_pressure_Pass        1 INCLUIR
#   action_under_pressure_Other        1 INCLUIR
#            trigger_type_Other        1 INCLUIR
#                    zone_Medio        2 EXCLUIR
# action_under_pressure_Dribble        2 EXCLUIR
#                        minute        4 EXCLUIR
#   action_under_pressure_Carry        4 EXCLUIR
#         nearest_teammate_dist        5 EXCLUIR
#         numerical_superiority        6 EXCLUIR
#               n_opponents_10m        7 EXCLUIR
#                    score_diff        8 EXCLUIR
#               is_counterpress        9 EXCLUIR
#              n_adversaries_5m       10 EXCLUIR
#            trigger_type_Carry       11 EXCLUIR
#                     had_block       12 EXCLUIR
#             trigger_type_Pass       13 EXCLUIR
#          trigger_type_Dribble       14 EXCLUIR

# %% [markdown]
# # 8. Comparação entre métodos de análise de variáveis

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.metrics import roc_auc_score, brier_score_loss

colunas_com_nan = df.columns[df.isna().any()].tolist()

if len(colunas_com_nan) > 0:
    for col in colunas_com_nan:
        qtd_nan = df[col].isna().sum()
        
        # Se a coluna for numérica (float ou int), preenche com a mediana
        if np.issubdtype(df[col].dtype, np.number):
            median_val = df[col].median()
            df[col] = df[col].fillna(median_val)
            print(f" -> [Numérica]  {col}: {qtd_nan} NaNs preenchidos com a mediana ({round(median_val, 2)})")
            
        # Se a coluna for de texto/objeto, preenche com 'Unknown'
        else:
            df[col] = df[col].fillna("Unknown")
            print(f" -> [Categórica] {col}: {qtd_nan} NaNs preenchidos com 'Unknown'")
else:
    print("[OK] Nenhuma feature apresentou valores nulos (NaN) no DataFrame.")
    
# --- MODELO 1: Relatório Estatístico (LRT / VIF / Sem Endogeneidade) ---

# Foco: Inferência pura do contexto inicial.
features_modelo_1 = [  # Aprovada no LRT estatístico do PDF
    "dist_to_goal",
    "zone",
    "action_under_pressure",
    "trigger_type",          # Tratada como categórica completa
    "voronoi_area_carrier",
    "numerical_superiority"  # Sobrevivente tática do trio no relatório
]

# --- MODELO 2: Seleção Integral do Boruta (Machine Learning) ---

# Nota: Para respeitar o design do Boruta no Statsmodels, dummificamos 
# manualmente as parciais categóricas aprovadas por ele.
df['action_Pass'] = (df['action_under_pressure'] == 'Pass').astype(int)
df['action_Other'] = (df['action_under_pressure'] == 'Other').astype(int)
df['zone_Defensivo'] = (df['zone'] == 'Defensivo').astype(int)
df['trigger_Other'] = (df['trigger_type'] == 'Other').astype(int)

features_modelo_2 = [
    "n_teammates_10m",        # Aprovada Boruta (Vencedora do trio colinear no ML)
    "voronoi_area_carrier",   # Aprovada Boruta
    "duration",               # Aprovada Boruta
    "dist_to_goal",           # Aprovada Boruta
    "nearest_opponent_dist",  # Aprovada Boruta
    "pressing_compactness",   # Aprovada Boruta
    "voronoi_area_presser",   # Aprovada Boruta
    "zone_Defensivo",         # Dummy específica aprovada pelo Boruta
    "action_Pass",            # Dummy específica aprovada pelo Boruta
    "action_Other",           # Dummy específica aprovada pelo Boruta
    "trigger_Other"           # Dummy específica aprovada pelo Boruta
]


# ==========================================
# 3. FUNÇÃO DE AJUSTE COM EFEITOS FIXOS (GLM)
# ==========================================
def treinar_modelo_pressing(df_dados, lista_features, nome_modelo):
    print(f"\n{'='*10} TREINANDO: {nome_modelo} {'='*10}")
    
    formula_componentes = []
    for feat in lista_features:
        # Garante o tratamento correto de strings residuais caso existam
        if df_dados[feat].dtype == 'object' or feat in ["trigger_type", "zone", "action_under_pressure"]:
            formula_componentes.append(f"C({feat})")
        else:
            formula_componentes.append(feat)
            
    # Adiciona C(team_name) para isolar o efeito fixo de cada seleção (Seção 2.5 da Proposta)
    formula = f"recovered ~ {' + '.join(formula_componentes)} + C(team_name)"
    
    # Ajuste por Máxima Verossimilhança via GLM Binomial (Regressão Logística)
    modelo = smf.glm(formula=formula, data=df_dados, family=sm.families.Binomial()).fit()
    
    print(modelo.summary())
    return modelo


# ==========================================
# 4. EXECUÇÃO DO TREINAMENTO
# ==========================================

modelo_1_relatorio = treinar_modelo_pressing(df, features_modelo_1, "Modelo 1 (Triagem univariada + VIF / LRT / Wald + Teste de permutação)")
modelo_2_boruta = treinar_modelo_pressing(df, features_modelo_2, "Modelo 2 (Boruta ML - 13 Vars)")


# ==========================================
# 5. QUADRO COMPARATIVO DE PERFORMANCE
# ==========================================
def avaliar_modelo(modelo, df_dados, nome):
    preds = modelo.predict(df_dados)
    
    auc = roc_auc_score(df_dados["recovered"], preds)
    brier = brier_score_loss(df_dados["recovered"], preds)
    
    # Cálculo robusto de Log-Loss para evitar quebras por probabilidades extremas (0 ou 1)
    preds_clipped = np.clip(preds, 1e-15, 1 - 1e-15)
    log_loss = -np.mean(
        df_dados["recovered"] * np.log(preds_clipped) + 
        (1 - df_dados["recovered"]) * np.log(1 - preds_clipped)
    )
    
    return {
        "Modelo": nome,
        "AUC-ROC (Poder Preditivo)": round(auc, 4),
        "Brier Score (Calibração)": round(brier, 4),
        "Log-Loss": round(log_loss, 4)
    }

# Gerando a tabela final
res_m1 = avaliar_modelo(modelo_1_relatorio, df, "Modelo 1 (Relatório Estatístico)")

res_m2 = avaliar_modelo(modelo_2_boruta, df, "Modelo 2 (Boruta ML)")

df_comparacao = pd.DataFrame([res_m1, res_m2])

print("\n" + "="*20 + " QUADRO COMPARATIVO DE PERFORMANCE " + "="*20)
print(df_comparacao.to_string(index=False))
print("="*75)
# Out:
#  -> [Numérica]  n_teammates_10m: 1959 NaNs preenchidos com a mediana (2.0)
#  -> [Numérica]  n_adversaries_5m: 1959 NaNs preenchidos com a mediana (1.0)
#  -> [Numérica]  n_opponents_10m: 1959 NaNs preenchidos com a mediana (2.0)
#  -> [Numérica]  nearest_teammate_dist: 1959 NaNs preenchidos com a mediana (0.0)
#  -> [Numérica]  nearest_opponent_dist: 1959 NaNs preenchidos com a mediana (2.86)
#  -> [Numérica]  numerical_superiority: 1959 NaNs preenchidos com a mediana (0.0)
#  -> [Numérica]  pressing_compactness: 1975 NaNs preenchidos com a mediana (10.25)
#  -> [Numérica]  voronoi_area_carrier: 2156 NaNs preenchidos com a mediana (82.92)
#  -> [Numérica]  voronoi_area_presser: 2156 NaNs preenchidos com a mediana (100.36)
#  -> [Numérica]  voronoi_n_opp_neighbors: 2156 NaNs preenchidos com a mediana (1.0)
#
# ========== TREINANDO: Modelo 1 (Triagem univariada + VIF / LRT / Wald + Teste de permutação) ==========
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              recovered   No. Observations:                15958
# Model:                            GLM   Df Residuals:                    15921
# Model Family:                Binomial   Df Model:                           36
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -9233.0
# Date:                Mon, 15 Jun 2026   Deviance:                       18466.
# Time:                        23:32:55   Pearson chi2:                 1.60e+04
# No. Iterations:                     4   Pseudo R-squ. (CS):            0.02865
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -0.8545      0.129     -6.640      0.000      -1.107      -0.602
# C(zone)[T.Defensivo]                    0.3013      0.122      2.474      0.013       0.063       0.540
# C(zone)[T.Medio]                       -0.0096      0.073     -0.132      0.895      -0.152       0.133
# C(action_under_pressure)[T.Carry]      -0.0690      0.068     -1.012      0.312      -0.203       0.065
# C(action_under_pressure)[T.Dribble]     0.5907      0.114      5.178      0.000       0.367       0.814
# C(action_under_pressure)[T.Other]       0.2956      0.075      3.930      0.000       0.148       0.443
# C(action_under_pressure)[T.Pass]       -0.2006      0.076     -2.645      0.008      -0.349      -0.052
# C(trigger_type)[T.Carry]               -0.0107      0.052     -0.207      0.836      -0.113       0.091
# C(trigger_type)[T.Dribble]              0.0126      0.161      0.078      0.938      -0.304       0.329
# C(trigger_type)[T.Other]                0.2759      0.058      4.752      0.000       0.162       0.390
# C(trigger_type)[T.Pass]                 0.0551      0.058      0.948      0.343      -0.059       0.169
# C(team_name)[T.Belgium]                -0.4721      0.124     -3.819      0.000      -0.714      -0.230
# C(team_name)[T.Croatia]                -0.5436      0.116     -4.691      0.000      -0.771      -0.316
# C(team_name)[T.Czech Republic]         -0.2605      0.113     -2.303      0.021      -0.482      -0.039
# C(team_name)[T.Denmark]                -0.2377      0.112     -2.125      0.034      -0.457      -0.018
# C(team_name)[T.England]                -0.3489      0.103     -3.374      0.001      -0.552      -0.146
# C(team_name)[T.Finland]                -0.6299      0.128     -4.932      0.000      -0.880      -0.380
# C(team_name)[T.France]                 -0.3669      0.122     -3.000      0.003      -0.607      -0.127
# C(team_name)[T.Germany]                -0.2293      0.126     -1.819      0.069      -0.476       0.018
# C(team_name)[T.Hungary]                -0.3850      0.132     -2.913      0.004      -0.644      -0.126
# C(team_name)[T.Italy]                  -0.3601      0.104     -3.456      0.001      -0.564      -0.156
# C(team_name)[T.Netherlands]            -0.1027      0.114     -0.901      0.367      -0.326       0.121
# C(team_name)[T.North Macedonia]        -0.0583      0.131     -0.445      0.656      -0.315       0.199
# C(team_name)[T.Poland]                 -0.1525      0.123     -1.238      0.216      -0.394       0.089
# C(team_name)[T.Portugal]               -0.1295      0.125     -1.034      0.301      -0.375       0.116
# C(team_name)[T.Russia]                 -0.1189      0.128     -0.930      0.352      -0.370       0.132
# C(team_name)[T.Scotland]               -0.2162      0.122     -1.770      0.077      -0.456       0.023
# C(team_name)[T.Slovakia]               -0.5481      0.124     -4.430      0.000      -0.791      -0.306
# C(team_name)[T.Spain]                  -0.0552      0.107     -0.518      0.604      -0.264       0.154
# C(team_name)[T.Sweden]                 -0.6217      0.132     -4.724      0.000      -0.880      -0.364
# C(team_name)[T.Switzerland]            -0.3655      0.109     -3.349      0.001      -0.579      -0.152
# C(team_name)[T.Turkey]                 -0.4186      0.124     -3.383      0.001      -0.661      -0.176
# C(team_name)[T.Ukraine]                -0.2100      0.110     -1.905      0.057      -0.426       0.006
# C(team_name)[T.Wales]                  -0.5414      0.126     -4.296      0.000      -0.788      -0.294
# dist_to_goal                            0.0004      0.002      0.239      0.811      -0.003       0.004
# voronoi_area_carrier                   -0.0002   4.49e-05     -5.291      0.000      -0.000      -0.000
# numerical_superiority                   0.0610      0.017      3.590      0.000       0.028       0.094
# =======================================================================================================
#
# ========== TREINANDO: Modelo 2 (Boruta ML - 13 Vars) ==========
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              recovered   No. Observations:                15958
# Model:                            GLM   Df Residuals:                    15923
# Model Family:                Binomial   Df Model:                           34
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -9235.3
# Date:                Mon, 15 Jun 2026   Deviance:                       18471.
# Time:                        23:32:56   Pearson chi2:                 1.60e+04
# No. Iterations:                     4   Pseudo R-squ. (CS):            0.02838
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -0.9301      0.145     -6.407      0.000      -1.215      -0.646
# C(team_name)[T.Belgium]            -0.4711      0.124     -3.812      0.000      -0.713      -0.229
# C(team_name)[T.Croatia]            -0.5531      0.116     -4.769      0.000      -0.780      -0.326
# C(team_name)[T.Czech Republic]     -0.2550      0.113     -2.255      0.024      -0.477      -0.033
# C(team_name)[T.Denmark]            -0.2473      0.112     -2.209      0.027      -0.467      -0.028
# C(team_name)[T.England]            -0.3660      0.103     -3.538      0.000      -0.569      -0.163
# C(team_name)[T.Finland]            -0.6158      0.128     -4.812      0.000      -0.867      -0.365
# C(team_name)[T.France]             -0.3643      0.122     -2.978      0.003      -0.604      -0.125
# C(team_name)[T.Germany]            -0.2209      0.126     -1.753      0.080      -0.468       0.026
# C(team_name)[T.Hungary]            -0.4107      0.132     -3.106      0.002      -0.670      -0.152
# C(team_name)[T.Italy]              -0.3705      0.104     -3.556      0.000      -0.575      -0.166
# C(team_name)[T.Netherlands]        -0.1006      0.114     -0.881      0.378      -0.324       0.123
# C(team_name)[T.North Macedonia]    -0.0784      0.131     -0.598      0.550      -0.336       0.179
# C(team_name)[T.Poland]             -0.1647      0.123     -1.336      0.182      -0.406       0.077
# C(team_name)[T.Portugal]           -0.1296      0.125     -1.035      0.301      -0.375       0.116
# C(team_name)[T.Russia]             -0.1144      0.128     -0.895      0.371      -0.365       0.136
# C(team_name)[T.Scotland]           -0.2212      0.122     -1.812      0.070      -0.461       0.018
# C(team_name)[T.Slovakia]           -0.5588      0.124     -4.510      0.000      -0.802      -0.316
# C(team_name)[T.Spain]              -0.0570      0.107     -0.534      0.593      -0.266       0.152
# C(team_name)[T.Sweden]             -0.6495      0.132     -4.933      0.000      -0.907      -0.391
# C(team_name)[T.Switzerland]        -0.3531      0.109     -3.239      0.001      -0.567      -0.139
# C(team_name)[T.Turkey]             -0.4286      0.124     -3.462      0.001      -0.671      -0.186
# C(team_name)[T.Ukraine]            -0.2068      0.110     -1.876      0.061      -0.423       0.009
# C(team_name)[T.Wales]              -0.5394      0.126     -4.282      0.000      -0.786      -0.293
# n_teammates_10m                     0.0915      0.018      4.971      0.000       0.055       0.128
# voronoi_area_carrier               -0.0002   4.52e-05     -4.413      0.000      -0.000      -0.000
# duration                           -0.1067      0.026     -4.167      0.000      -0.157      -0.056
# dist_to_goal                        0.0005      0.001      0.386      0.699      -0.002       0.003
# nearest_opponent_dist              -0.0182      0.012     -1.568      0.117      -0.041       0.005
# pressing_compactness                0.0036      0.007      0.552      0.581      -0.009       0.016
# voronoi_area_presser             6.867e-05   3.68e-05      1.865      0.062   -3.49e-06       0.000
# zone_Defensivo                      0.3044      0.064      4.791      0.000       0.180       0.429
# action_Pass                        -0.2404      0.049     -4.938      0.000      -0.336      -0.145
# action_Other                        0.2681      0.049      5.504      0.000       0.173       0.364
# trigger_Other                       0.2484      0.050      4.994      0.000       0.151       0.346
# ===================================================================================================
#
# ==================== QUADRO COMPARATIVO DE PERFORMANCE ====================
#                           Modelo  AUC-ROC (Poder Preditivo)  Brier Score (Calibração)  Log-Loss
# Modelo 1 (Relatório Estatístico)                     0.6069                    0.1958    0.5786
#             Modelo 2 (Boruta ML)                     0.6084                    0.1959    0.5787
# ===========================================================================

# %% [markdown]
# ## 9. Análise de resíduos por jogador

# %%
# ==============================================================================
# CÁLCULO DE MINUTOS JOGADOS POR JOGADOR
# ==============================================================================

lista_minutos_jogados = []

# 1. Iterar diretamente pela lista de partidas já carregada na memória
for match in matches:
    match_id = match['match_id']
    
    # 2. Carregar os eventos da partida específica a partir do diretório local correspondente
    # Usamos a mesma função 'load_json' que você já possui mapeada no notebook
    caminho_eventos = DATA_DIR / 'events' / f"{match_id}.json"
    
    try:
        eventos_partida = load_json(caminho_eventos)
    except FileNotFoundError:
        print(f"Aviso: Arquivo de eventos para a partida {match_id} não foi encontrado. Pulando...")
        continue
        
    # Converter a lista de dicionários de eventos em um DataFrame temporário para facilitar a manipulação
    df_ev = pd.DataFrame(eventos_partida)
    
    # Descobrir a duração total da partida (incluindo eventuais prorrogações)
    duracao_total = df_ev['minute'].max()
    
    # Dicionário temporário para rastrear a minutagem nesta partida específica
    minutos_partida = {}
    
    # A. Mapear quem começou jogando (Starting XI)
    # No JSON puro do StatsBomb, o tipo do evento vem dentro de um dicionário na chave 'type'
    df_starting = df_ev[df_ev['type'].apply(lambda x: x['name'] == 'Starting XI' if isinstance(x, dict) else False)]
    
    for _, row in df_starting.iterrows():
        # Captura o nome do time
        team_name = row['team']['name']
        # No JSON bruto, a escalação fica dentro do dicionário 'tactics'
        escalacao = row['tactics']['lineup']
        
        for jogador in escalacao:
            p_id = jogador['player']['id']
            p_name = jogador['player']['name']
            
            minutos_partida[p_id] = {
                'player_name': p_name,
                'team_name': team_name,
                'minuto_entrada': 0,
                'minuto_saida': duracao_total # Padrão temporário: jogou o jogo todo
            }
            
    # B. Mapear as substituições ocorridas na partida
    df_subs = df_ev[df_ev['type'].apply(lambda x: x['name'] == 'Substitution' if isinstance(x, dict) else False)]
    
    for _, row in df_subs.iterrows():
        minuto_sub = row['minute']
        team_name = row['team']['name']
        
        # Jogador que SAIU
        saiu_id = row['player']['id']
        if saiu_id in minutos_partida:
            minutos_partida[saiu_id]['minuto_saida'] = minuto_sub
            
        # Jogador que ENTROU (as informações extras ficam na chave 'substitution')
        entrou_id = row['substitution']['replacement']['id']
        entrou_name = row['substitution']['replacement']['name']
        
        # Registra o reserva que entrou em campo
        minutos_partida[entrou_id] = {
            'player_name': entrou_name,
            'team_name': team_name,
            'minuto_entrada': minuto_sub,
            'minuto_saida': duracao_total # Padrão: joga até o fim a partir do minuto que entrou
        }
        
    # C. Calcular o delta de minutos efetivos de cada jogador nesta partida
    for p_id, info in minutos_partida.items():
        minutos_em_campo = info['minuto_saida'] - info['minuto_entrada']
        
        lista_minutos_jogados.append({
            'match_id': match_id,
            'player_id': p_id,
            'player_name': info['player_name'],
            'team_name': info['team_name'],
            'minutes_played': minutos_em_campo
        })

# 3. Consolidar os dados de todas as partidas processadas locais
df_minutos_por_partida = pd.DataFrame(lista_minutos_jogados)

# 4. Agrupar por ID de jogador para somar o acumulado histórico do torneio
player_minutes = df_minutos_por_partida.groupby(['player_id', 'player_name', 'team_name'])['minutes_played'].sum().reset_index()

print("DataFrame 'player_minutes' gerado com sucesso localmente!")
print(f"Total de jogadores únicos processados: {len(player_minutes)}")

# Exibir uma prévia dos jogadores com mais minutos (comumente os finalistas)
player_minutes.sort_values(by='minutes_played', ascending=False).head(5)
# Out:
# DataFrame 'player_minutes' gerado com sucesso localmente!
# Total de jogadores únicos processados: 490
#      player_id              player_name team_name  minutes_played
# 193       7036     Gianluigi Donnarumma     Italy             745
# 191       7024  Jorge Luiz Frello Filho     Italy             730
# 36        3468          Jordan Pickford   England             711
# 204       7173         Leonardo Bonucci     Italy             702
# 21        3244              John Stones   England             696

# %%
# 5. Agrega o volume absoluto de pressões criadas na Euro 2020
df['player_id'] = pressures['player_id']
player_pressures_abs = df.groupby('player_id').size().reset_index(name='total_pressures_abs')

# 6. Extrai a média de qualidade individual (resíduos) por ID de jogador
player_quality = df.groupby('player_id')['residual'].mean().reset_index(name='qualidade_individual')

# 7. Junta as métricas de pressing com o DataFrame de minutos jogados
player_analysis = pd.merge(player_minutes, player_pressures_abs, on='player_id', how='inner')
player_analysis = pd.merge(player_analysis, player_quality, on='player_id', how='inner')

# 8. Calcula a métrica normalizada de intensidade (Pressões por 90)
player_analysis['pressures_per_90'] = (player_analysis['total_pressures_abs'] / player_analysis['minutes_played']) * 90

# 9. Aplica o filtro de corte por tempo amostral (ex: mínimo de 180 minutos = 2 jogos completos)
# Isso blinda o modelo contra reservas que jogaram 5 minutos e distorcem a taxa por 90
player_analysis_filtered = player_analysis[player_analysis['minutes_played'] >= 180].copy()

# 10. Atualiza os rankings baseados nas novas colunas
player_analysis_filtered['ranking_residual'] = player_analysis_filtered['qualidade_individual'].rank(ascending=False, method='min')
player_analysis_filtered['ranking_bruto_p90'] = player_analysis_filtered['pressures_per_90'].rank(ascending=False, method='min')

# Ordenar o resultado final pela métrica de qualidade
player_analysis_filtered = player_analysis_filtered.sort_values(by='qualidade_individual', ascending=False).reset_index(drop=True)

# %%
# ==============================================================================
# ANÁLISE DE RESÍDUOS POR JOGADOR COM NORMALIZAÇÃO
# ==============================================================================

results = modelo_1_relatorio

# 1. Extrair os resíduos de resposta e associar os IDs e metadados de volta
df['residual'] = results.resid_response
df['player_id'] = pressures['player_id']
df['player_name'] = pressures['player_name']
df['team_name'] = pressures['team_name']

# 2. Agregar o volume absoluto de pressões e a qualidade média por ID de jogador
# Agrupar por ID blinda o código contra jogadores homônimos na Euro
player_pressing_stats = df.groupby('player_id').agg(
    total_pressures_abs=('recovered', 'count'),
    residuo_medio=('residual', 'mean')
).reset_index()

# 3. Cruzar os dados de pressing com o DataFrame de minutos jogados (player_minutes)
# Isso trará os minutos em campo e validará os nomes/times corretos
player_analysis = pd.merge(
    player_minutes, 
    player_pressing_stats, 
    on='player_id', 
    how='inner'
)

# 4. Calcular a métrica de intensidade normalizada: Pressões por 90 minutos (P90)
player_analysis['pressures_per_90'] = (player_analysis['total_pressures_abs'] / player_analysis['minutes_played']) * 90

# 5. Filtrar por minutagem amostral segura (Mínimo de 180 minutos = 2 jogos completos)
# Isso evita o efeito de "amostra pequena" de reservas que jogaram 10 minutos
player_analysis_filtered = player_analysis[player_analysis['minutes_played'] >= 180].copy()

# 6. Construir os rankings comparativos para a análise tática
# - ranking_residual: Ordena pela qualidade individual pura (quem entrega mais que o esperado pelo contexto)
# - ranking_intensidade_p90: Ordena pelo volume puro de atividade por 90 minutos
player_analysis_filtered['ranking_residual'] = player_analysis_filtered['residuo_medio'].rank(ascending=False, method='min').astype(int)
player_analysis_filtered['ranking_intensidade_p90'] = player_analysis_filtered['pressures_per_90'].rank(ascending=False, method='min').astype(int)

# Diferença de ranking (Interpretação: valor positivo = jogador cuja eficiência real 
# supera e muito o seu volume aparente ou contexto defensivo do time)
player_analysis_filtered['dif_ranking'] = player_analysis_filtered['ranking_intensidade_p90'] - player_analysis_filtered['ranking_residual']

# Ordenar o relatório final pela métrica de qualidade individual (Resíduo Médio)
player_analysis_filtered = player_analysis_filtered.sort_values(by='residuo_medio', ascending=False).reset_index(drop=True)

# 7. Organizar as colunas para melhor legibilidade no relatório acadêmico
colunas_finais = [
    'player_id', 'player_name', 'team_name', 'minutes_played', 
    'total_pressures_abs', 'pressures_per_90', 'residuo_medio', 
    'ranking_residual', 'ranking_intensidade_p90', 'dif_ranking'
]
player_analysis_filtered = player_analysis_filtered[colunas_finais]

# 8. Salvar os resultados estruturados na pasta "variable_analysis"
os.makedirs('variable_analysis', exist_ok=True)
output_path = 'variable_analysis/residuos_por_jogador_p90.csv'
player_analysis_filtered.to_csv(output_path, index=False)

print(f"Análise P90 concluída com sucesso! Base de dados consolidada salva em: '{output_path}'")
print(f"Total de atletas analisados após os critérios de corte: {len(player_analysis_filtered)}")

# Exibir uma prévia dos 10 melhores pontuados pela eficiência individual
player_analysis_filtered.head(10)
# Out:
# Análise P90 concluída com sucesso! Base de dados consolidada salva em: 'variable_analysis/residuos_por_jogador_p90.csv'
# Total de atletas analisados após os critérios de corte: 265
#    player_id                    player_name team_name  minutes_played  total_pressures_abs  pressures_per_90  residuo_medio  ranking_residual  \
# 0      21532                Daniel Bachmann   Austria             402                    1          0.223881       0.632862                 1
# 1       5205  Rui Pedro dos Santos Patrício  Portugal             379                    1          0.237467       0.588424                 2
# 2       3323                   Tyrone Mings   England             201                    9          4.029851       0.263867                 3
# 3       6766        Gerard Moreno Balaguero     Spain             297                   32          9.696970       0.259911                 4
# 4       5639            Anga Dedryck Boyata   Belgium             184                   11          5.380435       0.258411                 5
# 5       4626                   Jan Bednarek    Poland             273                   28          9.230769       0.233627                 6
# 6       3593      Renato Júnior Luz Sanches  Portugal             228                   25          9.868421       0.219442                 7
# 7       5534              Simon Thorup Kjær   Denmark             542                   54          8.966790       0.154103                 8
# 8      20827              Vitalii Mykolenko   Ukraine             363                   41         10.165289       0.145636                 9
# 9      16502            László Kleinheisler   Hungary             248                   44         15.967742       0.138237                10
#
#    ranking_intensidade_p90  dif_ranking
# 0                      263          262
# 1                      261          259
# 2                      254          251
# 3                      195          191
# 4                      247          242
# 5                      205          199
# 6                      191          184
# 7                      212          204
# 8                      187          178
# 9                       95           85

# %%
# 1. Garantir que o dataframe original está ordenado pela qualidade (maior para menor resíduo)
player_analysis_filtered = player_analysis_filtered.sort_values(by='residuo_medio', ascending=False)

# 2. Agrupar por time e usar .head(5) para capturar os 5 melhores de cada um
# Como a base já está ordenada por qualidade, o .head(5) pegará os 5 maiores resíduos de cada país
top_5_per_team = player_analysis_filtered.groupby('team_name').head(5).copy()

# 3. Criar um ranking interno (1º ao 5º lugar) específico para dentro de cada seleção
# Ele classifica quem é o jogador mais eficiente de cada país com base no resíduo
top_5_per_team['ranking_no_time'] = top_5_per_team.groupby('team_name')['residuo_medio'].rank(
    ascending=False, 
    method='min'
).astype(int)

# 4. Selecionar e reordenar as colunas incluindo as novas métricas P90 e de tempo
colunas_destaque = [
    'team_name', 
    'ranking_no_time', 
    'player_name', 
    'minutes_played',         # Contexto de tempo em campo na Euro
    'total_pressures_abs',    # Volume bruto acumulado
    'pressures_per_90',       # Intensidade normalizada de pressing
    'residuo_medio',          # Métrica de qualidade individual (eficiência)
    'ranking_residual',       # Posição dele no ranking de qualidade mundial
    'ranking_intensidade_p90' # Posição dele no ranking de intensidade mundial
]
top_5_per_team = top_5_per_team[colunas_destaque]

# 5. Ordenar o DataFrame final por ordem alfabética do país e pelo ranking interno (1 a 5)
top_5_per_team = top_5_per_team.sort_values(by=['team_name', 'ranking_no_time']).reset_index(drop=True)

# 6. Salvar este novo DataFrame em um arquivo CSV separado
os.makedirs('variable_analysis', exist_ok=True)
output_path_teams = 'variable_analysis/top_5_jogadores_por_time_p90.csv'
top_5_per_team.to_csv(output_path_teams, index=False)

print(f"Destaques por time (Versão P90) salvos com sucesso em: '{output_path_teams}'")
print(f"Total de registros gerados (Seleções x Top 5): {len(top_5_per_team)}")

# Exibir uma prévia (ex: os destaques das primeiras seleções em ordem alfabética)
top_5_per_team.head(10)
# Out:
# Destaques por time (Versão P90) salvos com sucesso em: 'variable_analysis/top_5_jogadores_por_time_p90.csv'
# Total de registros gerados (Seleções x Top 5): 120
#   team_name  ranking_no_time          player_name  minutes_played  total_pressures_abs  pressures_per_90  residuo_medio  ranking_residual  \
# 0   Austria                1      Daniel Bachmann             402                    1          0.223881       0.632862                 1
# 1   Austria                2        Andreas Ulmer             188                   22         10.531915       0.107433                18
# 2   Austria                3       Xaver Schlager             374                   99         23.823529       0.091100                25
# 3   Austria                4   Martin Hinteregger             402                   42          9.402985       0.036072                74
# 4   Austria                5        Stefan Lainer             394                   80         18.274112       0.023913                95
# 5   Belgium                1  Anga Dedryck Boyata             184                   11          5.380435       0.258411                 5
# 6   Belgium                2     Thomas Vermaelen             303                   28          8.316832       0.112557                16
# 7   Belgium                3    Toby Alderweireld             378                   15          3.571429       0.085597                28
# 8   Belgium                4      Youri Tielemans             349                   51         13.151862       0.070716                35
# 9   Belgium                5       Jan Vertonghen             362                   21          5.220994       0.070418                36
#
#    ranking_intensidade_p90
# 0                      263
# 1                      180
# 2                       14
# 3                      203
# 4                       60
# 5                      247
# 6                      217
# 7                      257
# 8                      137
# 9                      248

# %%
# ================================================================
# GRÁFICO DE INTENSIDADE DE PRESSING VS RESÍDUOS MÉDIOS
# Só uma ideia, não sei se vamos usar
# ================================================================

import seaborn as sns

# 1. Configurar o estilo estético acadêmico
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize=(13, 9))

# 2. Plotar o gráfico de dispersão com a intensidade no Eixo X
sns.scatterplot(
    data=player_analysis_filtered, 
    x='pressures_per_90',         # ALTERADO: Agora usamos a métrica normalizada
    y='residuo_medio',      # Mantido: Resíduo Médio
    s=95,                          # Tamanho dos pontos
    color='#1b4f72',               # Azul escuro elegante
    alpha=0.7,                     # Transparência para densidade
    edgecolor='w', 
    linewidth=0.6,
    ax=ax
)

# 3. Definir e traçar as novas linhas divisórias dos quadrantes
x_mediana_p90 = player_analysis_filtered['pressures_per_90'].median()
y_baseline = 0.0  # Resíduo zero = comportamento médio esperado

# Linha vertical (Intensidade): Separa blocos intensos de blocos cadenciados
ax.axvline(x=x_mediana_p90, color='#7f8c8d', linestyle='--', linewidth=1.5, alpha=0.8, 
           label=f'Mediana de Intensidade ({x_mediana_p90:.1f} Pressões/90\')')

# Linha horizontal (Qualidade): Separa alta eficiência de baixa eficiência
ax.axhline(y=y_baseline, color='#c0392b', linestyle='-', linewidth=1.5, alpha=0.7, 
           label='Média Esperada pelo Modelo (Resíduo = 0)')

# 4. Adicionar os Rótulos Táticos nos quatro cantos (Ajustados para o conceito P90)
x_min, x_max = player_analysis_filtered['pressures_per_90'].min(), player_analysis_filtered['pressures_per_90'].max()
y_min, y_max = player_analysis_filtered['residuo_medio'].min(), player_analysis_filtered['residuo_medio'].max()

x_offset = (x_max - x_min) * 0.03
y_offset = (y_max - y_min) * 0.04

# Quadrante Superior Direito: Alta Intensidade / Alta Eficiência
ax.text(x_max - x_offset, y_max - y_offset, 'ELITE DISRUPTORS\n(Alta Intensidade P90 / Alta Eficiência)', 
        fontsize=10, weight='bold', color='#1e8449', ha='right', va='top', alpha=0.9)

# Quadrante Superior Esquerdo: Baixa Intensidade / Alta Eficiência
ax.text(x_min + x_offset, y_max - y_offset, 'CIRÚRGICOS / GEMS\n(Baixa Intensidade P90 / Alta Eficiência)', 
        fontsize=10, weight='bold', color='#2980b9', ha='left', va='top', alpha=0.9)

# Quadrante Inferior Direito: Alta Intensidade / Baixa Eficiência
ax.text(x_max - x_offset, y_min + y_offset, 'SYSTEM PLAYERS / WORKERS\n(Alta Intensidade P90 / Baixa Eficiência)', 
        fontsize=10, weight='bold', color='#d35400', ha='right', va='bottom', alpha=0.9)

# Quadrante Inferior Esquerdo: Baixa Intensidade / Baixa Eficiência
ax.text(x_min + x_offset, y_min + y_offset, 'UNDERPERFORMERS\n(Baixa Intensidade P90 / Baixa Eficiência)', 
        fontsize=10, weight='bold', color='#7f8c8d', ha='left', va='bottom', alpha=0.9)

# 5. Destacar os Outliers baseados no P90 e Qualidade
# Seleciona os 5 melhores em resíduo e os 3 mais intensos do torneio por 90'
players_to_annotate = pd.concat([
    player_analysis_filtered.head(5),
    player_analysis_filtered.sort_values(by='pressures_per_90', ascending=False).head(3)
]).drop_duplicates(subset=['player_name'])

for _, row in players_to_annotate.iterrows():
    ax.text(
        x=row['pressures_per_90'] + (x_max * 0.005), 
        y=row['residuo_medio'], 
        s=row['player_name'], 
        fontsize=9, 
        weight='semibold',
        alpha=0.85
    )

# 6. Ajustes de títulos e legendas
ax.set_title('Matriz de Quadrantes de Pressing (UEFA Euro 2020)', fontsize=14, pad=15, weight='bold')
ax.set_xlabel('Intensidade de Pressing (Ações de Pressão por 90 Minutos)', fontsize=11, labelpad=10)
ax.set_ylabel('Qualidade Individual (Resíduo Médio)', fontsize=11, labelpad=10)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=2, frameon=True)

# 7. Salvar o gráfico atualizado
os.makedirs('variable_analysis', exist_ok=True)
output_plot_path = 'variable_analysis/matriz_quadrantes_pressing_p90.png'
plt.savefig(output_plot_path, dpi=300, bbox_inches='tight')

plt.show()

print(f"Gráfico P90 gerado e salvo com sucesso em: '{output_plot_path}'")
# Out:
# Gráfico P90 gerado e salvo com sucesso em: 'variable_analysis/matriz_quadrantes_pressing_p90.png'

# %% [markdown]
# ## 10. Importância de características do pressing

# %%
results = modelo_1_relatorio

# 1. Extrair os coeficientes brutos e os p-valores do modelo
df_coeficientes = pd.DataFrame({
    'coeficiente_bruto': results.params,
    'p_valor': results.pvalues
}).reset_index().rename(columns={'index': 'variavel_tatica'})

# 2. Remover o Intercepto para focar apenas nas características do jogo
df_coeficientes = df_coeficientes[df_coeficientes['variavel_tatica'] != 'const'].copy()

# 3. Calcular a Razão de Chances (Odds Ratio - OR)
df_coeficientes['odds_ratio'] = np.exp(df_coeficientes['coeficiente_bruto'])

# 4. Calcular o impacto percentual na chance de recuperação para facilitar a leitura na banca
# Se OR = 1.30 -> Impacto de +30%. Se OR = 0.85 -> Impacto de -15%
df_coeficientes['impacto_percentual'] = (df_coeficientes['odds_ratio'] - 1) * 100

# 5. Filtrar apenas variáveis estatisticamente significativas (Confiança de 95%)
# Isso limpa variáveis que o modelo não tem certeza se ajudam ou atrapalham
df_efetividade_tatica = df_coeficientes[df_coeficientes['p_valor'] < 0.05].copy()

# 6. Ordenar do tipo de pressing mais efetivo para o menos efetivo
df_efetividade_tatica = df_efetividade_tatica.sort_values(by='impacto_percentual', ascending=False).reset_index(drop=True)

# 7. Formatar os números para ficarem bonitos no relatório acadêmico
df_efetividade_tatica['odds_ratio'] = df_efetividade_tatica['odds_ratio'].round(3)
df_efetividade_tatica['impacto_percentual'] = df_efetividade_tatica['impacto_percentual'].round(1)
df_efetividade_tatica['p_valor'] = df_efetividade_tatica['p_valor'].round(4)

# 8. Salvar os resultados na pasta de análises
# os.makedirs('variable_analysis', exist_ok=True)
# output_tatica_path = 'variable_analysis/efetividade_caracteristicas_pressing.csv'
# df_efetividade_tatica.to_csv(output_tatica_path, index=False)

# print(f"Análise de efetividade tática salva em: '{output_tatica_path}'")

# Exibir a tabela completa de gatilhos táticos ordenados por eficiência
df_efetividade_tatica
# Out:
# Análise de efetividade tática salva em: 'variable_analysis/efetividade_caracteristicas_pressing.csv'
#                         variavel_tatica  coeficiente_bruto  p_valor  odds_ratio  impacto_percentual
# 0   C(action_under_pressure)[T.Dribble]           0.590696   0.0000       1.805                80.5
# 1                  C(zone)[T.Defensivo]           0.301265   0.0134       1.352                35.2
# 2     C(action_under_pressure)[T.Other]           0.295618   0.0001       1.344                34.4
# 3              C(trigger_type)[T.Other]           0.275925   0.0000       1.318                31.8
# 4                 numerical_superiority           0.061038   0.0003       1.063                 6.3
# 5                  voronoi_area_carrier          -0.000238   0.0000       1.000                -0.0
# 6      C(action_under_pressure)[T.Pass]          -0.200628   0.0082       0.818               -18.2
# 7               C(team_name)[T.Denmark]          -0.237736   0.0336       0.788               -21.2
# 8        C(team_name)[T.Czech Republic]          -0.260480   0.0213       0.771               -22.9
# 9               C(team_name)[T.England]          -0.348896   0.0007       0.705               -29.5
# 10                C(team_name)[T.Italy]          -0.360083   0.0005       0.698               -30.2
# 11          C(team_name)[T.Switzerland]          -0.365541   0.0008       0.694               -30.6
# 12               C(team_name)[T.France]          -0.366864   0.0027       0.693               -30.7
# 13              C(team_name)[T.Hungary]          -0.384952   0.0036       0.680               -32.0
# 14               C(team_name)[T.Turkey]          -0.418640   0.0007       0.658               -34.2
# 15              C(team_name)[T.Belgium]          -0.472064   0.0001       0.624               -37.6
# 16                C(team_name)[T.Wales]          -0.541436   0.0000       0.582               -41.8
# 17              C(team_name)[T.Croatia]          -0.543630   0.0000       0.581               -41.9
# 18             C(team_name)[T.Slovakia]          -0.548144   0.0000       0.578               -42.2
# 19               C(team_name)[T.Sweden]          -0.621732   0.0000       0.537               -46.3
# 20              C(team_name)[T.Finland]          -0.629852   0.0000       0.533               -46.7
# 21                            Intercept          -0.854518   0.0000       0.425               -57.5
